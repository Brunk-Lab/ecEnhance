# %% [markdown]
# # ecDNA Detection Pipeline Batch Processing
#
# ## Introduction
#
# This Jupyter notebook implements an automated pipeline for detecting and classifying extrachromosomal circular DNA (ecDNA) in Fluorescence in situ Hybridization (FISH) images. The pipeline processes RGB FISH images paired with corresponding DAPI grayscale images to identify and count ecDNA and chromosome-associated objects. Below is a detailed explanation of each component, designed for clarity in supplementary materials
#
# ### Datasets
#
# - **RGB Images**: FISH images with probes (e.g., HER2, MYC) stored in `FACS-/proj/brunk_ecdna_cv_project/Poorya/FACS-FISH_redistribution_NCIH2170/version_2_Acc_87/4_batch_process/input_directory/FACS_241119/RGB`.
#
# - **DAPI Images**: Grayscale images highlighting nuclei, stored in `/proj/brunk_ecdna_cv_project/Poorya/FACS-FISH_redistribution_NCIH2170/version_2_Acc_87/4_batch_process/input_directory/FACS_241119/DAPI`.
#
# - **MIA Predicted Images**: Grayscale images predicted by MIA stored in
# `/proj/brunk_ecdna_cv_project/Poorya/FACS-FISH_redistribution_NCIH2170/version_2_Acc_87/4_batch_process/input_directory/FACS_241119/MIA`.
#
#
#
# ### Dependencies
#
# The following libraries are required. Ensure the specified versions are installed for reproducibility:
#
# - `opencv-python==4.1.1`: Image processing.
# - `numpy==1.25.0`: Numerical operations.
# - `pandas==4.11.0`: Data handling.
# - `matplotlib==3.8.4`: Plotting.
#
# Install via:
#
# `pip install opencv-python==4.1.1 numpy==1.25.0 pandas==4.11.0 matplotlib==3.8.4`

# %%
# Import Required Libraries
import os
import cv2
import numpy as np
import math
import csv
import json
from multiprocessing import Pool
from functools import partial
import time
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Parameter Optimization
#
# The pipeline uses parameters optimized via Bayesian Optimization, stored in best_params.json. If this file is missing, it falls back to default values. These parameters control all aspects of enhancement, detection, and classification, ensuring robustness and accuracy across diverse image sets

# %%
# Load Optimized Parameters with Fallback
# Parameters are loaded from 'best_params.json' if available; otherwise, default values are used.
default_params = {
    'kernel_size': 10.83,           # Size of the structuring element for top-hat filtering
    'clip_limit': 3.95,          # Contrast limit for CLAHE
    'tile_grid_size': 21.71,       # Tile size for CLAHE grid
    'strength': 4.666,            # Sharpening strength
    'cutoff': 68.44,              # Sigmoid cutoff value
    'gain': 23.14,                 # Sigmoid gain factor
    'chrom_kernel_size': 168.9,   # Kernel size for chromosome estimation in top-hat
    'dampening_factor': 0.3346,    # Intensity dampening factor for chromosome regions
    'merge_distance': 8.013,       # Distance threshold for merging close objects
    'min_area': 4.133,              # Minimum area for detected objects
    'max_area': 619.6,           # Maximum area for detected objects
    'white_value_threshold': 179.5,  # Brightness threshold for chromosome classification
    'white_saturation_threshold': 63.32  # Saturation threshold for chromosome classification
}

if os.path.exists("best_params.json"):
    with open("best_params.json", "r") as f:
        best_params = json.load(f)
    print("Loaded optimized parameters from best_params.json")
else:
    print("Warning: best_params.json not found, using default parameters")
    best_params = default_params
# Out:
# Loaded optimized parameters from best_params.json

# %% [markdown]
# ### Input Handling and Preprocessing:
#
# **RGB and DAPI Loading**: RGB images are loaded from a specified folder, and corresponding DAPI images are matched using unique identifiers extracted from filenames.
#
# **Masking:** Pixels in the RGB image where the DAPI image is black (indicating no nuclear material) are set to zero, focusing analysis on regions of interest.

# %% [markdown]
# ### Note on Commented Code
# Print statements and some file-saving operations (e.g., `cv2.imwrite` for final overlays) were commented out to reduce output clutter and disk usage. Uncomment these lines for debugging or to save additional outputs.

# %% [markdown]
# ## Utility and Helper Functions

# %%
def debug_save_image(image, name, step, out_folder, unique_id=""):
    """
    Saves an image to the specified folder with a step number, name, and unique identifier.
    Returns the file path.
    """
    if unique_id:
        filename = f"{unique_id}_{step:02d}_{name}.tif"
    else:
        filename = f"{step:02d}_{name}.tif"
    filepath = os.path.join(out_folder, filename)
    # Save with high quality (no compression for TIFF)
    cv2.imwrite(filepath, image, [int(cv2.IMWRITE_TIFF_COMPRESSION), 1])  # 1 = no compression
    #print(f"Saved: {filepath}")
    return filepath

def extract_unique_id(filename, suffixes):
    """
    Extracts the unique identifier from a filename.
    For example, if filename is "Sample1_Merge.tif" and suffixes is ["_Merge"], 
    then it returns "Sample1".
    We can pass a list of possible suffixes (e.g., ["_Merge", "_DAPI"]).
    """
    base = os.path.splitext(filename)[0]
    for suf in suffixes:
        if base.endswith(suf):
            return base[:-len(suf)]
    # If no suffix is found, return the whole base
    return base

def find_corresponding_dapi(unique_id, dapi_folder):
    """
    Searches the dapi_folder for a file whose unique id (extracted from its name) matches the given unique_id.
    For example, if unique_id is "Sample1", it looks for a file ending with "_DAPI" or "_DAPI_ROI".
    Returns the full path if found; otherwise, returns None.
    """
    # Define possible suffixes for DAPI images
    dapi_suffixes = ["_Merge.tif (RGB)", "_DAPI", "_DAPI.tif", "_Merge.tif (RGB)", "_Merge.tif(RGB)",
                     "_Merge.tif (RGB).tif", "_Merge.tif(RGB).tif","_Merge(RGB)", "_Merge (RGB)",
                     "_Merge(RGB).tif", "_Merge (RGB).tif", "_Merge"]
    for fname in os.listdir(dapi_folder):
        if not fname.lower().endswith(('.tif','.tiff','.png')):
            continue
        uid = extract_unique_id(fname, dapi_suffixes)
        if uid == unique_id:
            return os.path.join(dapi_folder, fname)
    return None

def mask_rgb_with_dapi(rgb_img, dapi_img):
    """
    Given an RGB image and its corresponding DAPI (grayscale) image, set pixels in the RGB image to black 
    wherever the DAPI image is black.
    """
    # Ensure dapi_img is single-channel
    if len(dapi_img.shape) != 2:
        dapi_img = cv2.cvtColor(dapi_img, cv2.COLOR_BGR2GRAY)
    mask = (dapi_img == 0)
    rgb_masked = rgb_img.copy()
    rgb_masked[mask] = 0
    return rgb_masked

# %% [markdown]
# ##  Image Enhancement Functions
#
# ### Image Enhancement:
# The RGB image is converted to grayscale to simplify processing.
# A four-step enhancement sequence is applied, with parameters optimized via Bayesian Optimization:
#
# - **Top-Hat Filtering:** Enhances small, bright objects (potential ecDNA) using a morphological operation with a structuring element of size `kernel_size`. Chromosome regions are estimated with a larger kernel `(chrom_kernel_size)` and their intensity is reduced by dampening_factor.
# - **Sharpening:** Increases edge clarity using a sharpening kernel scaled by `strength`.
# - **CLAHE:** Improves local contrast with `clip_limit` and `tile_grid_size`, adapting to varying image conditions.
# - **Sigmoid Transformation:** Adjusts intensity using `cutoff` and `gain` to enhance visibility of objects.

# %%
def top_hat_enhancement(gray, kernel_size, chrom_kernel_size, dampening_factor):
    """
    Apply top-hat enhancement to emphasize small, bright features while dampening chromosome regions.
    
    Parameters:
    - gray: Grayscale input image
    - kernel_size: Size of the structuring element for top-hat filtering
    - chrom_kernel_size: Size of the structuring element for chromosome estimation
    - dampening_factor: Factor to reduce intensity in chromosome regions
    """
    # Top-hat filtering to enhance small objects
    se = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (int(kernel_size), int(kernel_size)))
    opened = cv2.morphologyEx(gray, cv2.MORPH_OPEN, se)
    top_hat = cv2.subtract(gray, opened)
    top_hat_norm = cv2.normalize(top_hat, None, 0, 255, cv2.NORM_MINMAX, dtype=cv2.CV_8U)
    
    # Estimate chromosome regions and create a mask
    chrom_se = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (int(chrom_kernel_size), int(chrom_kernel_size)))
    chromosome_est = cv2.morphologyEx(gray, cv2.MORPH_CLOSE, chrom_se)
    _, chrom_mask = cv2.threshold(chromosome_est, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    
    # Dampen intensity in chromosome regions
    top_hat_soft = top_hat_norm.astype(np.float32)
    top_hat_soft[chrom_mask == 255] *= dampening_factor
    return np.clip(top_hat_soft, 0, 255).astype(np.uint8)

def apply_sharpening_gray(gray, strength):
    """Apply sharpening to enhance object edges."""
    kernel = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]], dtype=np.float32) * (strength / 5.0)
    return cv2.filter2D(gray, -1, kernel)

def custom_clahe(gray, clip_limit, tile_grid_size):
    """Apply CLAHE to improve local contrast."""
    clahe = cv2.createCLAHE(clipLimit=clip_limit, tileGridSize=(int(tile_grid_size), int(tile_grid_size)))
    return clahe.apply(gray)

def apply_sigmoid(gray, cutoff, gain):
    """Apply sigmoid transformation for intensity adjustment."""
    norm = gray.astype(np.float32) / 255.0
    c = cutoff / 255.0
    out = 1.0 / (1.0 + np.exp(-gain * (norm - c)))
    return (out * 255).astype(np.uint8)


def process_images(input_image, params, save_debug=False, output_folder=None, unique_id=""):
    """
    Process an input image through the enhancement pipeline: top-hat → sharpening → CLAHE → sigmoid.
    
    Parameters:
    - input_image: Input RGB or grayscale image
    - params: Dictionary of optimized parameters
    - save_debug: Whether to save intermediate images
    - output_folder: Folder for saving debug images
    - unique_id: Unique identifier for the image
    """
    # Convert to grayscale if RGB
    if input_image.ndim == 3:
        gray = cv2.cvtColor(cv2.convertScaleAbs(input_image), cv2.COLOR_BGR2GRAY)
    else:
        gray = cv2.convertScaleAbs(input_image)
    
    simple_gray = gray.copy()
    
    # Enhancement pipeline
    th = top_hat_enhancement(gray, kernel_size=params['kernel_size'], 
                             chrom_kernel_size=params['chrom_kernel_size'], 
                             dampening_factor=params['dampening_factor'])
    sharp = apply_sharpening_gray(th, strength=params['strength'])
    clahe_img = custom_clahe(sharp, clip_limit=params['clip_limit'], 
                             tile_grid_size=params['tile_grid_size'])
    enhanced = apply_sigmoid(clahe_img, cutoff=params['cutoff'], gain=params['gain'])
    debug_save_image(simple_gray, "simple_gray", 1, output_folder, unique_id)
    
    # Save debug images if requested
    if save_debug and output_folder:
        debug_save_image(enhanced, "enhanced_gray", 2, output_folder, unique_id)
    
    return simple_gray, enhanced

# %% [markdown]
# ##  Object Detection & Overlay Functions
#
# ### **Object Detection:**
# - **Thresholding:** Applies Otsu’s method to binarize the enhanced image.
# - **Morphological Cleaning:** Uses opening and closing operations with a small elliptical kernel to remove noise and connect fragmented objects.
# - **Connected Components:** Identifies objects, filtering by area (`min_area` to `max_area`).
# - **Merging:** Combines objects closer than `merge_distance` based on centroid distance.
#
# ### Classification and Annotation:
#
# - **Classification:** Objects are classified as `“chromosome”` or `“ecDNA”` using the RGB image’s HSV values. Regions with high brightness `(white_value_threshold)` and low saturation `(white_saturation_threshold)` are labeled as chromosomes; others are ecDNA.
# - **Annotation:** Bounding boxes are drawn on both the enhanced grayscale and RGB images, with counts recorded.

# %%
def merge_close_objects(objects, merge_distance):
    """Merge objects that are closer than the specified distance."""
    merged_objects = []
    taken = [False] * len(objects)
    for i in range(len(objects)):
        if taken[i]:
            continue
        current = objects[i].copy()
        for j in range(i + 1, len(objects)):
            if taken[j]:
                continue
            if math.dist(current["centroid"], objects[j]["centroid"]) < merge_distance:
                x1, y1, w1, h1 = current["bbox"]
                x2, y2, w2, h2 = objects[j]["bbox"]
                current["bbox"] = (min(x1, x2), min(y1, y2), max(x1 + w1, x2 + w2) - min(x1, x2), 
                                   max(y1 + h1, y2 + h2) - min(y1, y2))
                cx1, cy1 = current["centroid"]
                cx2, cy2 = objects[j]["centroid"]
                current["centroid"] = ((cx1 + cx2) / 2.0, (cy1 + cy2) / 2.0)
                current["area"] += objects[j]["area"]
                taken[j] = True
        merged_objects.append(current)
        taken[i] = True
    return merged_objects

def classify_as_white_or_ecDNA(roi, white_value_threshold, white_saturation_threshold):
    """Classify an object as 'chromosome' or 'ecDNA' based on HSV values."""
    hsv_roi = cv2.cvtColor(roi, cv2.COLOR_BGR2HSV)
    _, S_mean, V_mean, _ = cv2.mean(hsv_roi)
    return "chromosome" if (V_mean > white_value_threshold and S_mean < white_saturation_threshold) else "ecDNA"



def annotate_objects(merged_objects, rgb_image_path, simple_gray, output_folder, unique_id, params):
    """
    Annotate detected objects on both the RGB and simple grayscale images, and count classifications.

    Parameters:
    - merged_objects (list): List of detected objects with bbox, centroid, and area.
    - rgb_image_path (str): Path to the RGB image.
    - simple_gray (numpy.ndarray): Simple grayscale image to annotate.
    - output_folder (str): Folder to save annotated images.
    - unique_id (str): Unique identifier for the image.
    - params (dict): Dictionary of optimized parameters.

    Returns:
    - dict: Counts of chromosomes and ecDNA.
    """
    # Load and annotate the RGB image
    rgb_img = cv2.imread(rgb_image_path, cv2.IMREAD_COLOR)
    if rgb_img is None:
        print(f"Could not load RGB image: {rgb_image_path}")
        return {}

    # Ensure simple_gray is a valid grayscale image
    if simple_gray is None or len(simple_gray.shape) != 2:
        print(f"Invalid simple grayscale image for {unique_id}. Skipping grayscale annotation.")
        annotated_gray = None
    else:
        # Convert grayscale to BGR for colored annotations
        annotated_gray = cv2.cvtColor(simple_gray, cv2.COLOR_GRAY2BGR)

    # Initialize counts
    counts = {"chromosome": 0, "ecDNA": 0}
    marker_size = 6  # Size of the top-left corner marker

    # Use the original RGB image without enhancement
    annotated_rgb = rgb_img.copy()

    # Create an overlay layer for semi-transparent annotations
    overlay_rgb = np.zeros_like(annotated_rgb, dtype=np.uint8)
    if annotated_gray is not None:
        overlay_gray = np.zeros_like(annotated_gray, dtype=np.uint8)

    # Annotate the RGB image
    for obj in merged_objects:
        x, y, w, h = obj["bbox"]
        roi = rgb_img[y:y+h, x:x+w]
        label = classify_as_white_or_ecDNA(roi, params['white_value_threshold'], params['white_saturation_threshold'])
        counts[label] += 1

        # Set color: green for ecDNA, white for chromosomes
        color = (0, 255, 0) if label == "ecDNA" else (255, 255, 255)

        # Draw bounding box on overlay (thinner line)
        cv2.rectangle(overlay_rgb, (x, y), (x+w, y+h), color, 1)

        # Draw centroid (smaller)
        cx, cy = obj["centroid"]
        cv2.circle(overlay_rgb, (int(cx), int(cy)), 1, (0, 0, 255), -1)

        # Add text label for chromosomes (smaller font)
        if label == "chromosome":
            cv2.putText(overlay_rgb, "chromosome", (x, y - 10), 
                        cv2.FONT_HERSHEY_SIMPLEX, 0.4, color, 1)

        # Draw marker in top-left corner (smaller and on overlay)
        for mx in range(x, x + marker_size):
            for my in range(y, y + marker_size):
                if mx < overlay_rgb.shape[1] and my < overlay_rgb.shape[0]:
                    overlay_rgb[my, mx] = color

    # Apply alpha blending for RGB annotations
    alpha = 0.35  # Transparency factor (0.0 = fully transparent, 1.0 = fully opaque)
    annotated_rgb = cv2.addWeighted(annotated_rgb, 1.0, overlay_rgb, alpha, 0.0)

    # Save the annotated RGB image with high quality
    debug_save_image(annotated_rgb, "annotated_rgb", 5, output_folder, unique_id)

    # Annotate the grayscale image if available
    if annotated_gray is not None:
        for obj in merged_objects:
            x, y, w, h = obj["bbox"]
            label = classify_as_white_or_ecDNA(rgb_img[y:y+h, x:x+w], 
                                               params['white_value_threshold'], 
                                               params['white_saturation_threshold'])

            # Set color: green for ecDNA, white for chromosomes
            color = (0, 255, 0) if label == "ecDNA" else (255, 255, 255)

            # Draw bounding box on overlay (thinner line)
            cv2.rectangle(overlay_gray, (x, y), (x+w, y+h), color, 1)

            # Draw centroid (smaller)
            cx, cy = obj["centroid"]
            cv2.circle(overlay_gray, (int(cx), int(cy)), 1, (0, 0, 255), -1)

            # Add text label for chromosomes (smaller font)
            if label == "chromosome":
                cv2.putText(overlay_gray, "chromosome", (x, y - 10), 
                            cv2.FONT_HERSHEY_SIMPLEX, 0.4, color, 1)

            # Draw marker in top-left corner (smaller and on overlay)
            for mx in range(x, x + marker_size):
                for my in range(y, y + marker_size):
                    if mx < overlay_gray.shape[1] and my < overlay_gray.shape[0]:
                        overlay_gray[my, mx] = color

        # Apply alpha blending for grayscale annotations
        annotated_gray = cv2.addWeighted(annotated_gray, 1.0, overlay_gray, alpha, 0.0)

        # Save the annotated grayscale image with high quality
        debug_save_image(annotated_gray, "annotated_gray", 6, output_folder, unique_id)

    return counts

def object_detection_and_overlay(enhanced_img, rgb_img_path, simple_gray, output_folder, unique_id, params):
    """
    Detect objects in the enhanced image and overlay them on both grayscale and RGB images.
    
    Parameters:
    - enhanced_img: Enhanced grayscale image
    - rgb_img_path: Path to the RGB image
    - simple_gray: Simple grayscale image to annotate
    - output_folder: Folder for saving output images
    - unique_id: Unique identifier for the image
    - params: Dictionary of optimized parameters
    """
    # Threshold and clean the image
    _, thresh = cv2.threshold(enhanced_img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (2, 2))
    cleaned = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel)
    cleaned = cv2.morphologyEx(cleaned, cv2.MORPH_CLOSE, kernel)
    
    # Detect connected components
    num_labels, _, stats, centroids = cv2.connectedComponentsWithStats(cleaned, connectivity=8)
    objects = [{"bbox": (stats[i, 0], stats[i, 1], stats[i, 2], stats[i, 3]), 
                "area": stats[i, 4], 
                "centroid": centroids[i]}
               for i in range(1, num_labels) if params['min_area'] <= stats[i, 4] <= params['max_area']]
    
    # Merge close objects
    merged_objects = merge_close_objects(objects, merge_distance=params['merge_distance'])
    
    # Overlay on enhanced grayscale
    enhanced_color = cv2.cvtColor(enhanced_img, cv2.COLOR_GRAY2BGR)
    for obj in merged_objects:
        x, y, w, h = obj["bbox"]
        cv2.rectangle(enhanced_color, (x, y), (x+w, y+h), (0, 255, 0), 1)
    debug_save_image(enhanced_color, "overlay_on_gray", 4, output_folder, unique_id)
    
    # Annotate on both RGB and simple grayscale images
    counts = annotate_objects(merged_objects, rgb_img_path, simple_gray, output_folder, unique_id, params)
    
    return len(merged_objects), merged_objects, counts



def convert_obj(obj):
    """Convert object data to a JSON-serializable format."""
    return {
        "bbox": tuple(int(x) for x in obj["bbox"]),
        "centroid": tuple(float(x) for x in obj["centroid"]),
        "area": float(obj["area"])
    }

# %% [markdown]
# ## Main Processing Pipeline (First Part)

# %%
def process_single_image(args, params, rgb_folder, dapi_folder, output_folder):
    """
    Process a single RGB image and its corresponding DAPI image.

    Parameters:
    - args (tuple): Contains (fname, dapi_path)
    - params (dict): Optimized parameters
    - rgb_folder (str): Path to RGB images
    - dapi_folder (str): Path to DAPI images
    - output_folder (str): Path to save outputs

    Returns:
    - dict: Metrics for the image (filename, unique_id, Total, chromosome, ecDNA)
    - tuple: (unique_id, ref_objects) for storing reference data
    """
    fname, dapi_path = args
    try:
        rgb_path = os.path.join(rgb_folder, fname)
        rgb_img = cv2.imread(rgb_path, cv2.IMREAD_COLOR)
        if rgb_img is None or rgb_img.ndim != 3:
            print(f"Skipping {fname}: Not a valid RGB image.")
            return None, None

        # Extract unique id
        rgb_suffixes = ["_Merge.tif (RGB)", "_DAPI", "_DAPI.tif", "_Merge.tif (RGB)", "_Merge.tif(RGB)",
                        "_Merge.tif (RGB).tif", "_Merge.tif(RGB).tif","_Merge(RGB)", "_Merge (RGB)",
                        "_Merge(RGB).tif", "_Merge (RGB).tif", "_Merge", "_Merge ", "_Merge.tif"]
        unique_id = extract_unique_id(fname, rgb_suffixes)

        # Load and mask with DAPI
        if dapi_path is not None:
            dapi_img = cv2.imread(dapi_path, cv2.IMREAD_GRAYSCALE)
            if dapi_img is not None:
                new_rgb = mask_rgb_with_dapi(rgb_img, dapi_img)
            else:
                print(f"Could not load DAPI image for {unique_id}. Using original RGB.")
                new_rgb = rgb_img  # Avoid copy if not necessary
        else:
            print(f"No corresponding DAPI found for {unique_id}.")
            new_rgb = rgb_img

        # Save new RGB
        new_rgb_path = os.path.join(output_folder, f"{unique_id}_1_newRGB.tif")
        cv2.imwrite(new_rgb_path, new_rgb)

        # Process the image
        simple_gray, enhanced = process_images(new_rgb, params, save_debug=False, 
                                               output_folder=output_folder, unique_id=unique_id)

        # Detect and annotate objects, passing simple_gray
        total_count, merged_objects, counts = object_detection_and_overlay(
            enhanced, new_rgb_path, simple_gray, output_folder, unique_id, params
        )

        # Store reference data
        ref_objects = [convert_obj(o) for o in merged_objects]

        # Return metrics and reference data
        metrics = {
            'filename': fname,
            'unique_id': unique_id,
            'Total': total_count,
            'chromosome': counts.get("chromosome", 0),
            'ecDNA': counts.get("ecDNA", 0)
        }
        return metrics, (unique_id, ref_objects)

    except Exception as e:
        print(f"Error processing {fname}: {e}")
        return None, None
    
    
    

def main_pipeline(rgb_folder, dapi_folder, output_folder, metrics_csv_path, params):
    """
    Main pipeline to process RGB and DAPI images in parallel, detect objects, and save metrics.

    Parameters:
    - rgb_folder: Folder containing RGB images
    - dapi_folder: Folder containing DAPI images
    - output_folder: Folder to save output images and metrics
    - metrics_csv_path: Path to save the metrics CSV file
    - params: Dictionary of optimized parameters
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Preload all RGB files and their corresponding DAPI paths
    image_pairs = []
    rgb_files = [fname for fname in os.listdir(rgb_folder) if fname.lower().endswith(('.tif', '.tiff', '.png'))]
    for fname in rgb_files:
        unique_id = extract_unique_id(fname, ["_Merge.tif (RGB)", "_DAPI", "_DAPI.tif", "_Merge.tif (RGB)",
                                              "_Merge.tif(RGB)", "_Merge.tif (RGB).tif", "_Merge.tif(RGB).tif",
                                             "_Merge(RGB)", "_Merge (RGB)", "_Merge(RGB).tif", "_Merge (RGB).tif", "_Merge"])
        dapi_path = find_corresponding_dapi(unique_id, dapi_folder)
        image_pairs.append((fname, dapi_path))

    # Set up parallel processing
    num_workers = min(os.cpu_count(), 8)  # Limit to 8 workers to manage memory usage
    print(f"Using {num_workers} workers for parallel processing.")

    # Process images in parallel
    process_func = partial(process_single_image, params=params, rgb_folder=rgb_folder, 
                           dapi_folder=dapi_folder, output_folder=output_folder)
    
    metrics_list = []
    ref_data = {}
    with Pool(processes=num_workers) as pool:
        results = pool.map(process_func, image_pairs)
    
    # Collect results
    for metrics, ref_entry in results:
        if metrics is not None:
            metrics_list.append(metrics)
        if ref_entry is not None:
            unique_id, ref_objects = ref_entry
            ref_data[unique_id] = ref_objects

    # Write metrics to CSV all at once
    csv_path = os.path.join(output_folder, "metrics_summary.csv")
    with open(csv_path, 'w', newline='') as csvfile:
        fieldnames = ['filename', 'unique_id', 'Total', 'chromosome', 'ecDNA']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for metrics in metrics_list:
            writer.writerow(metrics)

    # Save reference objects to JSON
    json_path = os.path.join(output_folder, "ref_objects.json")
    with open(json_path, "w") as jf:
        json.dump(ref_data, jf)

    print(f"Processing complete. Metrics saved to {csv_path}")

# %% [markdown]
# ### Output:
#
# - **Metrics:** Total object count and counts of chromosomes and ecDNA are saved in a CSV file (metrics_summary.csv).
# - **Reference Data:** Object details (bounding boxes, centroids, areas) are saved in a JSON file (ref_objects.json).
# - **Debug Images:** Intermediate images (e.g., masked RGB, enhanced grayscale, annotated RGB) are saved with step numbers for validation.

# %%
# Run the Pipeline
rgb_folder = r"/proj/brunk_ecdna_cv_project/Poorya/FACS-FISH_redistribution_NCIH2170/version_2_Acc_87/4_batch_process/input_directory/FACS_241119/RGB"  # Replace with your RGB image folder path
dapi_folder = r"/proj/brunk_ecdna_cv_project/Poorya/FACS-FISH_redistribution_NCIH2170/version_2_Acc_87/4_batch_process/input_directory/FACS_241119/DAPI"  # Replace with your DAPI image folder path
output_folder = r"/proj/brunk_ecdna_cv_project/Poorya/FACS-FISH_redistribution_NCIH2170/version_2_Acc_87/4_batch_process/Final_Output/FACS_241119_Output"  # Replace with your output folder path
metrics_csv_path = os.path.join(output_folder, "metrics_summary.csv")

start_time = time.time()
main_pipeline(rgb_folder, dapi_folder, output_folder, metrics_csv_path, best_params)
print(f"First part runtime: {time.time() - start_time:.2f} seconds")
# Out:
# Using 8 workers for parallel processing.
# No corresponding DAPI found for H2170_TOTAL_HER2_G2_2502_125.
# No corresponding DAPI found for H2170_HIGH_HER2_G0_2411_27.
# No corresponding DAPI found for H2170_TOTAL_HER2_G2_2502_52.
# Processing complete. Metrics saved to /proj/brunk_ecdna_cv_project/Poorya/FACS-FISH_redistribution_NCIH2170/version_2_Acc_87/4_batch_process/Final_Output/FACS_241119_Output/metrics_summary.csv
# First part runtime: 2989.35 seconds

# %%
import os
import cv2
import json
import csv
import math
import numpy as np

##############################
#  Helper & Segmentation Functions
##############################

def debug_save_image(image, name, step, out_folder, unique_id=""):
    """Save image to disk with a step number and unique identifier."""
    if unique_id:
        filename = f"{unique_id}_{step:02d}_{name}.png"
    else:
        filename = f"{step:02d}_{name}.png"
    filepath = os.path.join(out_folder, filename)
    cv2.imwrite(filepath, image)
    #print(f"Saved: {filepath}")
    return filepath

def compute_iou(bboxA, bboxB):
    """Compute Intersection over Union (IoU) for two bounding boxes."""
    xA = max(bboxA[0], bboxB[0])
    yA = max(bboxA[1], bboxB[1])
    xB = min(bboxA[0] + bboxA[2], bboxB[0] + bboxB[2])
    yB = min(bboxA[1] + bboxA[3], bboxB[1] + bboxB[3])
    if xB < xA or yB < yA:
        return 0.0
    interArea = (xB - xA) * (yB - yA)
    boxAArea = bboxA[2] * bboxA[3]
    boxBArea = bboxB[2] * bboxB[3]
    iou = interArea / float(boxAArea + boxBArea - interArea)
    return iou

def match_with_partial(ref_objects, mia_objects, iou_full=0.01, iou_partial=0.001, distance_threshold=30.0):
    """
    Match objects between reference and MIA predictions.
    Returns:
      full_matches: list of (ref_index, mia_index) where IoU >= iou_full.
      partial_matches: list of (ref_index, mia_index) where IoU between iou_partial and iou_full or centroids are very close.
      unmatched_ref: set of indices in ref_objects not matched.
      unmatched_mia: set of indices in mia_objects not matched.
    """
    full_matches = []
    partial_matches = []
    unmatched_ref = set(range(len(ref_objects)))
    unmatched_mia = set(range(len(mia_objects)))
    
    for i, ref_obj in enumerate(ref_objects):
        ref_bbox = ref_obj["bbox"]
        for j, mia_obj in enumerate(mia_objects):
            if j not in unmatched_mia:
                continue
            mia_bbox = mia_obj["bbox"]
            iou = compute_iou(ref_bbox, mia_bbox)
            if iou >= iou_full:
                full_matches.append((i, j))
                unmatched_ref.discard(i)
                unmatched_mia.discard(j)
                break
            elif iou >= iou_partial:
                partial_matches.append((i, j))
                unmatched_ref.discard(i)
                unmatched_mia.discard(j)
                break
            else:
                dist = math.dist(ref_obj["centroid"], mia_obj["centroid"])
                if dist < distance_threshold:
                    partial_matches.append((i, j))
                    unmatched_ref.discard(i)
                    unmatched_mia.discard(j)
                    break
    return full_matches, partial_matches, unmatched_ref, unmatched_mia

def compute_metrics(full_matches, partial_matches, unmatched_ref, unmatched_mia):
    """Compute TP, partial TP, FP, and FN from matching results."""
    TP = len(full_matches)
    TP_partial = len(partial_matches)
    FN = len(unmatched_ref)
    FP = len(unmatched_mia)
    return TP, TP_partial, FP, FN

def segment_mia_mask(mia_mask_path, min_area=1, max_area=500, unique_id=""):
    """
    Segments the MIA predicted mask:
      1. Loads the binary MIA mask.
      2. Applies morphological closing to fill holes.
      3. Extracts connected components.
    Returns a list of detected predicted objects.
    """
    mia_mask = cv2.imread(mia_mask_path, cv2.IMREAD_GRAYSCALE)
    if mia_mask is None:
        raise IOError(f"Could not load MIA mask: {mia_mask_path}")
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3, 3))
    mia_filled = cv2.morphologyEx(mia_mask, cv2.MORPH_CLOSE, kernel)
    
    num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(mia_filled, connectivity=8)
    ecDNA_mia_objects = []
    for label_id in range(1, num_labels):  # skip background
        x, y, w, h, area = stats[label_id]
        cx, cy = centroids[label_id]
        if area < min_area or area > max_area:
            continue
        ecDNA_mia_objects.append({
            "label_id": label_id,
            "bbox": (x, y, w, h),
            "area": area,
            "centroid": (cx, cy)
        })
    return ecDNA_mia_objects, labels

def overlay_two_images(image1, image2, alpha=0.5):
    """Blend two images using alpha blending."""
    return cv2.addWeighted(image1, alpha, image2, 1 - alpha, 0)

def visualize_matches(ref_image_path, ref_objects, mia_objects, 
                      full_matches, partial_matches, unmatched_ref, unmatched_mia, 
                      out_folder, unique_id=""):
    """
    Creates an overlay visualization on the reference image:
      - Green: Full matches (TP)
      - Cyan: Partial matches
      - Red: False negatives (reference objects missed by MIA)
      - Blue: False positives (extra objects from MIA predictions)
    Saves the final overlay image with matching details.
    """
    # Load the reference image (we assume it's grayscale; if not, adjust accordingly)
    base_img = cv2.imread(ref_image_path, cv2.IMREAD_GRAYSCALE)
    if base_img is None:
        print("Error: Could not load reference image for visualization.")
        return
    # Convert to color so we can draw colored markers
    vis_img = cv2.cvtColor(base_img, cv2.COLOR_GRAY2BGR)
    
    # Draw full matches (TP) in green
    for (i, j) in full_matches:
        cx, cy = ref_objects[i]["centroid"]
        cv2.circle(vis_img, (int(cx), int(cy)), 5, (0, 255, 0), -1)
    
    # Draw partial matches in cyan
    for (i, j) in partial_matches:
        cx, cy = ref_objects[i]["centroid"]
        cv2.circle(vis_img, (int(cx), int(cy)), 5, (255, 255, 0), -1)
    
    # Draw false negatives (reference objects missed) in red
    for i in unmatched_ref:
        cx, cy = ref_objects[i]["centroid"]
        cv2.circle(vis_img, (int(cx), int(cy)), 5, (0, 0, 255), -1)
    
    # Draw false positives (extra MIA predictions) in blue
    for j in unmatched_mia:
        cx, cy = mia_objects[j]["centroid"]
        cv2.circle(vis_img, (int(cx), int(cy)), 5, (255, 0, 0), -1)
    
    # Save the visualization image
    vis_path = os.path.join(out_folder, f"{unique_id}_final_matches.tif")
    cv2.imwrite(vis_path, vis_img)
    #print(f"Saved detailed matching visualization: {vis_path}")

##############################
#  Second-Part Pipeline
##############################

def update_metrics_with_mia(existing_csv, ref_objects_json, output_folder, mia_folder, updated_csv_path,
                            ref_overlay_gray_suffix="_04_overlay_on_gray.tif",
                            ref_annotated_rgb_suffix="_05_annotated_rgb.tif"):
    """
    For each image (row) from the existing CSV (from part 1):
      - Use the unique_id to locate the saved reference overlays.
      - Load the corresponding reference objects from ref_objects_json.
      - Locate and segment the MIA predicted image (without enhancing it).
      - Match MIA objects to the stored reference objects.
      - Compute metrics: TP, TP_partial, FN, FP, and MIA_total.
      - Create final overlays by blending the MIA mask with the reference overlays.
      - Update the CSV row with the new metrics.
      - Write an updated copy of the CSV.
    """
    # Load existing CSV rows
    rows = []
    with open(existing_csv, 'r', newline='') as f:
        reader = csv.DictReader(f)
        for row in reader:
            rows.append(row)
    
    # Load stored reference objects (from part 1)
    with open(ref_objects_json, 'r') as jf:
        ref_data = json.load(jf)  # expected format: { unique_id: [ {bbox, centroid, area}, ... ], ... }
    
    for row in rows:
        unique_id = row.get("unique_id", "").strip()
        if not unique_id:
            # If missing, derive from filename
            fname = row.get("filename", "")
            unique_id = os.path.splitext(fname)[0].strip()
            row["unique_id"] = unique_id
        
        print(f"Processing unique_id: '{unique_id}'")
        
        # Get stored reference objects
        if unique_id not in ref_data:
            print(f"No reference objects for {unique_id}. Skipping update for this entry.")
            continue
        ref_objects = ref_data[unique_id]
        
        # Build expected file paths for the reference overlay images
        ref_gray_path = os.path.join(output_folder, f"{unique_id}{ref_overlay_gray_suffix}")
        ref_rgb_path = os.path.join(output_folder, f"{unique_id}{ref_annotated_rgb_suffix}")
        #print(f"Looking for ref_gray: '{ref_gray_path}'")
        #print(f"Looking for ref_rgb: '{ref_rgb_path}'")
        if not os.path.exists(ref_gray_path) or not os.path.exists(ref_rgb_path):
            print(f"Missing reference overlays for {unique_id}. Skipping update for this entry.")
            continue
        
        # Find corresponding MIA predicted image from mia_folder
        mia_path = None
        for fname in os.listdir(mia_folder):
            if fname.lower().endswith(('.tif','.tiff','.png')) and unique_id in fname:
                mia_path = os.path.join(mia_folder, fname)
                break
        if not mia_path:
            print(f"No MIA predicted image for {unique_id}. Skipping update for this entry.")
            continue
        
        # Segment the MIA predicted image
        try:
            mia_objects, _ = segment_mia_mask(mia_path, min_area=1, max_area=500, unique_id=unique_id)
        except Exception as e:
            print(f"Error segmenting MIA image for {unique_id}: {e}")
            continue
        mia_total = len(mia_objects)
        
        # Compute matching between stored reference objects and MIA objects
        full_matches, partial_matches, unmatched_ref, unmatched_mia = match_with_partial(
            ref_objects, mia_objects, iou_full=0.01, iou_partial=0.001, distance_threshold=30.0)
        TP, TP_partial, FP, FN = compute_metrics(full_matches, partial_matches, unmatched_ref, unmatched_mia)

        # Visualize matches
        visualize_matches(ref_gray_path, ref_objects, mia_objects,
                          full_matches, partial_matches, unmatched_ref, unmatched_mia,
                          output_folder, unique_id)
        
        # Load the reference overlay images and the MIA image for overlay visualization
        ref_gray_img = cv2.imread(ref_gray_path, cv2.IMREAD_GRAYSCALE)
        ref_rgb_img = cv2.imread(ref_rgb_path, cv2.IMREAD_COLOR)
        mia_img = cv2.imread(mia_path, cv2.IMREAD_GRAYSCALE)
        if ref_gray_img is None or ref_rgb_img is None or mia_img is None:
            print(f"Error loading images for {unique_id}. Skipping update for this entry.")
            continue
        
        # Create final overlays by blending the MIA predicted mask with each reference overlay
        ref_gray_color = cv2.cvtColor(ref_gray_img, cv2.COLOR_GRAY2BGR)
        mia_color = cv2.cvtColor(mia_img, cv2.COLOR_GRAY2BGR)
        final_overlay_gray = overlay_two_images(ref_gray_color, mia_color, alpha=0.7)
        final_overlay_gray_path = os.path.join(output_folder, f"{unique_id}_07_final_overlay_gray.tif")
        #cv2.imwrite(final_overlay_gray_path, final_overlay_gray)
        
        final_overlay_rgb = overlay_two_images(ref_rgb_img, mia_color, alpha=0.7)
        final_overlay_rgb_path = os.path.join(output_folder, f"{unique_id}_08_final_overlay_rgb.tif")
        #cv2.imwrite(final_overlay_rgb_path, final_overlay_rgb)
        
        # Update the CSV row with new metrics
        row["MIA_total"] = mia_total
        row["TP"] = TP
        row["TP_partial"] = TP_partial
        row["FN"] = FN
        row["FP"] = FP
        row["ref_total"] = len(ref_objects)
        
        print(f"Updated {unique_id}: ref_total={len(ref_objects)}, MIA_total={mia_total}, TP={TP}, TP_partial={TP_partial}, FN={FN}, FP={FP}")
    
    # Write updated CSV (copy of part-1 CSV updated)
    with open(updated_csv_path, 'w', newline='') as f:
        fieldnames = rows[0].keys()
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        for r in rows:
            writer.writerow(r)
    
    print(f"MIA validation update complete. Updated CSV saved to {updated_csv_path}")

# %%
# Define the folder paths (update these to match your environment):
output_folder = r"/proj/brunk_ecdna_cv_project/Poorya/FACS-FISH_redistribution_NCIH2170/version_2_Acc_87/4_batch_process/Final_Output/FACS_241119_Output"     # Folder containing your overlay images
mia_folder = r"/proj/brunk_ecdna_cv_project/Poorya/FACS-FISH_redistribution_NCIH2170/version_2_Acc_87/4_batch_process/input_directory/FACS_241119/MIA"       # Folder with MIA predicted images
existing_csv = os.path.join(output_folder, "metrics_summary.csv")  # CSV produced in part 1
ref_objects_json = os.path.join(output_folder, "ref_objects.json")  # The JSON file you saved from part 1
updated_csv_path = os.path.join(output_folder, "updated_ecDNA_counts.csv")

# Now call the update pipeline:
start_time = time.time()
update_metrics_with_mia(existing_csv, ref_objects_json, output_folder, mia_folder, updated_csv_path,
                        ref_overlay_gray_suffix="_04_overlay_on_gray.tif",
                        ref_annotated_rgb_suffix="_05_annotated_rgb.tif")
print(f"Second part runtime: {time.time() - start_time:.2f} seconds")
# Out:
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_1'
# Updated H2170_HIGH_HER2_G1_2501_1: ref_total=180, MIA_total=99, TP=3, TP_partial=34, FN=143, FP=62
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_11'
# Updated H2170_LOW_HER2_G2_2502_11: ref_total=103, MIA_total=101, TP=1, TP_partial=14, FN=88, FP=86
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_80'
# Updated H2170_LOW_HER2_G0_2411_80: ref_total=103, MIA_total=44, TP=13, TP_partial=17, FN=73, FP=14
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_55'
# Updated H2170_TOTAL_HER2_G1_2501_55: ref_total=250, MIA_total=90, TP=13, TP_partial=77, FN=160, FP=0
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_8'
# Updated H2170_LOW_HER2_G2_2502_8: ref_total=223, MIA_total=67, TP=0, TP_partial=39, FN=184, FP=28
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_92'
# Updated H2170_TOTAL_HER2_G0_2411_92: ref_total=370, MIA_total=188, TP=112, TP_partial=62, FN=196, FP=14
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_111'
# Updated H2170_LOW_HER2_G1_2501_111: ref_total=110, MIA_total=21, TP=10, TP_partial=10, FN=90, FP=1
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_129'
# Updated H2170_TOTAL_HER2_G1_2501_129: ref_total=153, MIA_total=78, TP=35, TP_partial=40, FN=78, FP=3
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_71'
# Updated H2170_HIGH_HER2_G1_2501_71: ref_total=255, MIA_total=208, TP=132, TP_partial=63, FN=60, FP=13
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_54'
# Updated H2170_LOW_HER2_G0_2411_54: ref_total=114, MIA_total=110, TP=34, TP_partial=30, FN=50, FP=46
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_123'
# Updated H2170_HIGH_HER2_G2_2502_123: ref_total=544, MIA_total=198, TP=48, TP_partial=140, FN=356, FP=10
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_52'
# Updated H2170_TOTAL_HER2_G0_2411_52: ref_total=233, MIA_total=165, TP=94, TP_partial=60, FN=79, FP=11
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_98'
# Updated H2170_LOW_HER2_G2_2502_98: ref_total=121, MIA_total=81, TP=39, TP_partial=36, FN=46, FP=6
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_62'
# Updated H2170_HIGH_HER2_G0_2411_62: ref_total=401, MIA_total=355, TP=177, TP_partial=114, FN=110, FP=64
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_62'
# Updated H2170_LOW_HER2_G0_2411_62: ref_total=138, MIA_total=47, TP=12, TP_partial=13, FN=113, FP=22
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_106'
# Updated H2170_HIGH_HER2_G2_2502_106: ref_total=433, MIA_total=59, TP=24, TP_partial=35, FN=374, FP=0
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_54'
# Updated H2170_TOTAL_HER2_G2_2502_54: ref_total=272, MIA_total=161, TP=64, TP_partial=92, FN=116, FP=5
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_1'
# Updated H2170_LOW_HER2_G2_2502_1: ref_total=178, MIA_total=80, TP=4, TP_partial=36, FN=138, FP=40
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_53'
# Updated H2170_HIGH_HER2_G2_2502_53: ref_total=222, MIA_total=88, TP=42, TP_partial=46, FN=134, FP=0
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_103'
# Updated H2170_HIGH_HER2_G1_2501_103: ref_total=240, MIA_total=99, TP=52, TP_partial=45, FN=143, FP=2
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_94'
# Updated H2170_LOW_HER2_G1_2501_94: ref_total=162, MIA_total=50, TP=22, TP_partial=27, FN=113, FP=1
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_56'
# Updated H2170_TOTAL_HER2_G2_2502_56: ref_total=135, MIA_total=46, TP=14, TP_partial=27, FN=94, FP=5
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_12'
# Updated H2170_TOTAL_HER2_G1_2501_12: ref_total=241, MIA_total=244, TP=6, TP_partial=119, FN=116, FP=119
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_43'
# Updated H2170_HIGH_HER2_G2_2502_43: ref_total=346, MIA_total=166, TP=59, TP_partial=102, FN=185, FP=5
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_78'
# Updated H2170_TOTAL_HER2_G2_2502_78: ref_total=198, MIA_total=115, TP=39, TP_partial=74, FN=85, FP=2
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_48'
# Updated H2170_HIGH_HER2_G2_2502_48: ref_total=154, MIA_total=118, TP=81, TP_partial=34, FN=39, FP=3
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_121'
# Updated H2170_HIGH_HER2_G2_2502_121: ref_total=339, MIA_total=220, TP=114, TP_partial=93, FN=132, FP=13
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_12'
# Updated H2170_LOW_HER2_G2_2502_12: ref_total=76, MIA_total=367, TP=2, TP_partial=49, FN=25, FP=316
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_20'
# Updated H2170_LOW_HER2_G1_2501_20: ref_total=74, MIA_total=31, TP=10, TP_partial=13, FN=51, FP=8
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_120'
# Updated H2170_HIGH_HER2_G1_2501_120: ref_total=517, MIA_total=326, TP=151, TP_partial=167, FN=199, FP=8
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_40'
# Updated H2170_TOTAL_HER2_G2_2502_40: ref_total=180, MIA_total=52, TP=16, TP_partial=34, FN=130, FP=2
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_84'
# Updated H2170_TOTAL_HER2_G0_2411_84: ref_total=407, MIA_total=201, TP=119, TP_partial=74, FN=214, FP=8
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_8'
# Updated H2170_TOTAL_HER2_G2_2502_8: ref_total=230, MIA_total=157, TP=0, TP_partial=37, FN=193, FP=120
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_73'
# Updated H2170_TOTAL_HER2_G1_2501_73: ref_total=301, MIA_total=103, TP=41, TP_partial=57, FN=203, FP=5
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_29'
# Updated H2170_LOW_HER2_G0_2411_29: ref_total=90, MIA_total=81, TP=4, TP_partial=20, FN=66, FP=57
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_33'
# Updated H2170_TOTAL_HER2_G1_2501_33: ref_total=154, MIA_total=55, TP=17, TP_partial=36, FN=101, FP=2
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_19'
# Updated H2170_LOW_HER2_G0_2411_19: ref_total=107, MIA_total=105, TP=6, TP_partial=24, FN=77, FP=75
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_87'
# Updated H2170_HIGH_HER2_G2_2502_87: ref_total=395, MIA_total=306, TP=130, TP_partial=169, FN=96, FP=7
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_115'
# Updated H2170_LOW_HER2_G2_2502_115: ref_total=275, MIA_total=119, TP=37, TP_partial=81, FN=157, FP=1
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_126'
# Updated H2170_LOW_HER2_G2_2502_126: ref_total=368, MIA_total=133, TP=44, TP_partial=83, FN=241, FP=6
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_9A'
# Updated H2170_HIGH_HER2_G1_2501_9A: ref_total=399, MIA_total=120, TP=25, TP_partial=95, FN=279, FP=0
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_35'
# Updated H2170_HIGH_HER2_G2_2502_35: ref_total=377, MIA_total=153, TP=38, TP_partial=109, FN=230, FP=6
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_92'
# Updated H2170_LOW_HER2_G1_2501_92: ref_total=103, MIA_total=64, TP=29, TP_partial=32, FN=42, FP=3
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_121'
# Updated H2170_HIGH_HER2_G0_2411_121: ref_total=350, MIA_total=222, TP=131, TP_partial=80, FN=139, FP=11
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_10'
# Updated H2170_HIGH_HER2_G0_2411_10: ref_total=126, MIA_total=331, TP=2, TP_partial=51, FN=73, FP=278
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_26'
# Updated H2170_LOW_HER2_G2_2502_26: ref_total=122, MIA_total=74, TP=41, TP_partial=29, FN=52, FP=4
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_100'
# Updated H2170_TOTAL_HER2_G1_2501_100: ref_total=105, MIA_total=33, TP=15, TP_partial=17, FN=73, FP=1
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_119'
# Updated H2170_LOW_HER2_G2_2502_119: ref_total=105, MIA_total=72, TP=45, TP_partial=16, FN=44, FP=11
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_58'
# Updated H2170_TOTAL_HER2_G0_2411_58: ref_total=383, MIA_total=264, TP=111, TP_partial=140, FN=132, FP=13
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_16B'
# Updated H2170_TOTAL_HER2_G1_2501_16B: ref_total=443, MIA_total=195, TP=64, TP_partial=124, FN=255, FP=7
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_69'
# Updated H2170_LOW_HER2_G0_2411_69: ref_total=124, MIA_total=119, TP=30, TP_partial=32, FN=62, FP=57
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_123'
# Updated H2170_LOW_HER2_G1_2501_123: ref_total=184, MIA_total=28, TP=6, TP_partial=22, FN=156, FP=0
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_40B'
# Updated H2170_LOW_HER2_G0_2411_40B: ref_total=329, MIA_total=147, TP=42, TP_partial=98, FN=189, FP=7
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_65'
# Updated H2170_LOW_HER2_G0_2411_65: ref_total=89, MIA_total=18, TP=10, TP_partial=5, FN=74, FP=3
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_106'
# Updated H2170_TOTAL_HER2_G0_2411_106: ref_total=548, MIA_total=363, TP=190, TP_partial=139, FN=219, FP=34
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_10'
# Updated H2170_TOTAL_HER2_G1_2501_10: ref_total=97, MIA_total=87, TP=0, TP_partial=26, FN=71, FP=61
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_64'
# Updated H2170_LOW_HER2_G0_2411_64: ref_total=154, MIA_total=117, TP=83, TP_partial=26, FN=45, FP=8
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_88'
# Updated H2170_HIGH_HER2_G2_2502_88: ref_total=110, MIA_total=68, TP=42, TP_partial=17, FN=51, FP=9
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_11'
# Updated H2170_LOW_HER2_G1_2501_11: ref_total=135, MIA_total=76, TP=2, TP_partial=30, FN=103, FP=44
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_78'
# Updated H2170_LOW_HER2_G2_2502_78: ref_total=242, MIA_total=82, TP=40, TP_partial=40, FN=162, FP=2
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_116'
# Updated H2170_LOW_HER2_G1_2501_116: ref_total=315, MIA_total=115, TP=45, TP_partial=64, FN=206, FP=6
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_116'
# Updated H2170_TOTAL_HER2_G0_2411_116: ref_total=302, MIA_total=225, TP=132, TP_partial=65, FN=105, FP=28
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_114'
# Updated H2170_LOW_HER2_G1_2501_114: ref_total=131, MIA_total=30, TP=12, TP_partial=13, FN=106, FP=5
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_10'
# Updated H2170_LOW_HER2_G1_2501_10: ref_total=112, MIA_total=28, TP=0, TP_partial=6, FN=106, FP=22
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_12'
# Updated H2170_LOW_HER2_G0_2411_12: ref_total=275, MIA_total=47, TP=1, TP_partial=23, FN=251, FP=23
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_11'
# Updated H2170_HIGH_HER2_G0_2411_11: ref_total=149, MIA_total=91, TP=0, TP_partial=15, FN=134, FP=76
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_44'
# Updated H2170_TOTAL_HER2_G1_2501_44: ref_total=176, MIA_total=56, TP=12, TP_partial=44, FN=120, FP=0
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_124'
# Updated H2170_TOTAL_HER2_G2_2502_124: ref_total=400, MIA_total=169, TP=58, TP_partial=106, FN=236, FP=5
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_23'
# Updated H2170_TOTAL_HER2_G0_2411_23: ref_total=215, MIA_total=116, TP=67, TP_partial=34, FN=114, FP=15
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_3'
# Updated H2170_TOTAL_HER2_G1_2501_3: ref_total=277, MIA_total=102, TP=4, TP_partial=43, FN=230, FP=55
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_39'
# Updated H2170_LOW_HER2_G0_2411_39: ref_total=255, MIA_total=229, TP=50, TP_partial=90, FN=115, FP=89
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_17'
# Updated H2170_TOTAL_HER2_G2_2502_17: ref_total=153, MIA_total=139, TP=100, TP_partial=23, FN=30, FP=16
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_2'
# Updated H2170_HIGH_HER2_G0_2411_2: ref_total=586, MIA_total=258, TP=131, TP_partial=125, FN=330, FP=2
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_100'
# Updated H2170_HIGH_HER2_G2_2502_100: ref_total=158, MIA_total=142, TP=103, TP_partial=32, FN=23, FP=7
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_22'
# Updated H2170_TOTAL_HER2_G2_2502_22: ref_total=208, MIA_total=134, TP=49, TP_partial=82, FN=77, FP=3
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_4'
# Updated H2170_LOW_HER2_G1_2501_4: ref_total=162, MIA_total=62, TP=1, TP_partial=32, FN=129, FP=29
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_91'
# Updated H2170_HIGH_HER2_G2_2502_91: ref_total=234, MIA_total=194, TP=134, TP_partial=50, FN=50, FP=10
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_38'
# Updated H2170_LOW_HER2_G0_2411_38: ref_total=122, MIA_total=17, TP=8, TP_partial=4, FN=110, FP=5
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_121'
# Updated H2170_TOTAL_HER2_G0_2411_121: ref_total=313, MIA_total=206, TP=132, TP_partial=69, FN=112, FP=5
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_104'
# Updated H2170_HIGH_HER2_G0_2411_104: ref_total=807, MIA_total=524, TP=314, TP_partial=186, FN=307, FP=24
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_61'
# Updated H2170_HIGH_HER2_G2_2502_61: ref_total=235, MIA_total=170, TP=76, TP_partial=87, FN=72, FP=7
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_99'
# Updated H2170_LOW_HER2_G1_2501_99: ref_total=74, MIA_total=43, TP=24, TP_partial=10, FN=40, FP=9
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_101'
# Updated H2170_LOW_HER2_G1_2501_101: ref_total=120, MIA_total=9, TP=4, TP_partial=4, FN=112, FP=1
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_20'
# Updated H2170_HIGH_HER2_G1_2501_20: ref_total=263, MIA_total=182, TP=97, TP_partial=82, FN=84, FP=3
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_40'
# Updated H2170_TOTAL_HER2_G0_2411_40: ref_total=271, MIA_total=76, TP=45, TP_partial=25, FN=201, FP=6
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_86'
# Updated H2170_LOW_HER2_G2_2502_86: ref_total=67, MIA_total=21, TP=11, TP_partial=7, FN=49, FP=3
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_130'
# Updated H2170_HIGH_HER2_G1_2501_130: ref_total=429, MIA_total=266, TP=116, TP_partial=143, FN=170, FP=7
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_43C'
# Updated H2170_TOTAL_HER2_G2_2502_43C: ref_total=180, MIA_total=59, TP=24, TP_partial=28, FN=128, FP=7
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_90'
# Updated H2170_HIGH_HER2_G2_2502_90: ref_total=428, MIA_total=164, TP=73, TP_partial=86, FN=269, FP=5
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_108'
# Updated H2170_TOTAL_HER2_G1_2501_108: ref_total=140, MIA_total=57, TP=29, TP_partial=26, FN=85, FP=2
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_91'
# Updated H2170_LOW_HER2_G1_2501_91: ref_total=56, MIA_total=9, TP=2, TP_partial=4, FN=50, FP=3
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_71'
# Updated H2170_LOW_HER2_G2_2502_71: ref_total=229, MIA_total=135, TP=76, TP_partial=52, FN=101, FP=7
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_115'
# Updated H2170_LOW_HER2_G0_2411_115: ref_total=209, MIA_total=128, TP=51, TP_partial=44, FN=114, FP=33
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_20'
# Updated H2170_TOTAL_HER2_G0_2411_20: ref_total=317, MIA_total=120, TP=70, TP_partial=32, FN=215, FP=18
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_50'
# Updated H2170_HIGH_HER2_G0_2411_50: ref_total=430, MIA_total=227, TP=138, TP_partial=77, FN=215, FP=12
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_70'
# Updated H2170_LOW_HER2_G0_2411_70: ref_total=216, MIA_total=87, TP=38, TP_partial=37, FN=141, FP=12
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_35'
# Updated H2170_LOW_HER2_G1_2501_35: ref_total=182, MIA_total=70, TP=23, TP_partial=45, FN=114, FP=2
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_81'
# Updated H2170_LOW_HER2_G2_2502_81: ref_total=300, MIA_total=84, TP=17, TP_partial=63, FN=220, FP=4
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_90'
# Updated H2170_LOW_HER2_G1_2501_90: ref_total=88, MIA_total=29, TP=12, TP_partial=15, FN=61, FP=2
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_93'
# Updated H2170_LOW_HER2_G0_2411_93: ref_total=121, MIA_total=50, TP=28, TP_partial=7, FN=86, FP=15
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_33'
# Updated H2170_HIGH_HER2_G2_2502_33: ref_total=553, MIA_total=277, TP=98, TP_partial=170, FN=285, FP=9
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_87'
# Updated H2170_LOW_HER2_G2_2502_87: ref_total=213, MIA_total=90, TP=39, TP_partial=48, FN=126, FP=3
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_130'
# Updated H2170_TOTAL_HER2_G2_2502_130: ref_total=107, MIA_total=48, TP=19, TP_partial=27, FN=61, FP=2
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_67'
# Updated H2170_HIGH_HER2_G2_2502_67: ref_total=206, MIA_total=137, TP=80, TP_partial=51, FN=75, FP=6
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_16'
# Updated H2170_HIGH_HER2_G1_2501_16: ref_total=228, MIA_total=80, TP=35, TP_partial=44, FN=149, FP=1
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_47'
# Updated H2170_TOTAL_HER2_G2_2502_47: ref_total=307, MIA_total=146, TP=38, TP_partial=106, FN=163, FP=2
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_125'
# Updated H2170_TOTAL_HER2_G2_2502_125: ref_total=256, MIA_total=47, TP=31, TP_partial=13, FN=212, FP=3
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_106'
# Updated H2170_TOTAL_HER2_G2_2502_106: ref_total=368, MIA_total=323, TP=204, TP_partial=109, FN=55, FP=10
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_53'
# Updated H2170_TOTAL_HER2_G0_2411_53: ref_total=619, MIA_total=114, TP=20, TP_partial=92, FN=507, FP=2
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_103'
# Updated H2170_TOTAL_HER2_G0_2411_103: ref_total=215, MIA_total=37, TP=9, TP_partial=21, FN=185, FP=7
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_50'
# Updated H2170_TOTAL_HER2_G2_2502_50: ref_total=183, MIA_total=58, TP=25, TP_partial=32, FN=126, FP=1
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_28'
# Updated H2170_HIGH_HER2_G1_2501_28: ref_total=220, MIA_total=165, TP=118, TP_partial=38, FN=64, FP=9
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_95'
# Updated H2170_HIGH_HER2_G2_2502_95: ref_total=115, MIA_total=55, TP=40, TP_partial=11, FN=64, FP=4
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_52'
# Updated H2170_LOW_HER2_G0_2411_52: ref_total=140, MIA_total=45, TP=13, TP_partial=17, FN=110, FP=15
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_37'
# Updated H2170_HIGH_HER2_G0_2411_37: ref_total=116, MIA_total=61, TP=27, TP_partial=22, FN=67, FP=12
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_7'
# Updated H2170_HIGH_HER2_G1_2501_7: ref_total=387, MIA_total=128, TP=28, TP_partial=100, FN=259, FP=0
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_33'
# Updated H2170_LOW_HER2_G1_2501_33: ref_total=46, MIA_total=52, TP=29, TP_partial=8, FN=9, FP=15
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_57'
# Updated H2170_HIGH_HER2_G1_2501_57: ref_total=347, MIA_total=339, TP=241, TP_partial=65, FN=41, FP=33
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_42'
# Updated H2170_LOW_HER2_G0_2411_42: ref_total=82, MIA_total=46, TP=15, TP_partial=15, FN=52, FP=16
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_105'
# Updated H2170_TOTAL_HER2_G2_2502_105: ref_total=86, MIA_total=38, TP=24, TP_partial=10, FN=52, FP=4
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_25'
# Updated H2170_HIGH_HER2_G0_2411_25: ref_total=248, MIA_total=155, TP=63, TP_partial=50, FN=135, FP=42
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_98'
# Updated H2170_HIGH_HER2_G1_2501_98: ref_total=257, MIA_total=85, TP=35, TP_partial=49, FN=173, FP=1
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_14'
# Updated H2170_HIGH_HER2_G2_2502_14: ref_total=192, MIA_total=23, TP=4, TP_partial=18, FN=170, FP=1
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_35'
# Updated H2170_LOW_HER2_G0_2411_35: ref_total=85, MIA_total=19, TP=5, TP_partial=6, FN=74, FP=8
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_129'
# Updated H2170_TOTAL_HER2_G2_2502_129: ref_total=255, MIA_total=139, TP=55, TP_partial=71, FN=129, FP=13
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_17A'
# Updated H2170_TOTAL_HER2_G0_2411_17A: ref_total=385, MIA_total=216, TP=150, TP_partial=59, FN=176, FP=7
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_92'
# Updated H2170_LOW_HER2_G0_2411_92: ref_total=119, MIA_total=44, TP=19, TP_partial=18, FN=82, FP=7
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_72'
# Updated H2170_TOTAL_HER2_G0_2411_72: ref_total=143, MIA_total=52, TP=24, TP_partial=23, FN=96, FP=5
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_100'
# Updated H2170_LOW_HER2_G1_2501_100: ref_total=56, MIA_total=28, TP=5, TP_partial=16, FN=35, FP=7
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_62'
# Updated H2170_TOTAL_HER2_G0_2411_62: ref_total=391, MIA_total=223, TP=148, TP_partial=63, FN=180, FP=12
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_110'
# Updated H2170_TOTAL_HER2_G2_2502_110: ref_total=301, MIA_total=163, TP=71, TP_partial=86, FN=144, FP=6
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_54B'
# Updated H2170_HIGH_HER2_G2_2502_54B: ref_total=394, MIA_total=154, TP=72, TP_partial=76, FN=246, FP=6
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_70'
# Updated H2170_HIGH_HER2_G1_2501_70: ref_total=159, MIA_total=77, TP=44, TP_partial=29, FN=86, FP=4
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_77'
# Updated H2170_LOW_HER2_G2_2502_77: ref_total=152, MIA_total=85, TP=50, TP_partial=27, FN=75, FP=8
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_90'
# Updated H2170_LOW_HER2_G2_2502_90: ref_total=167, MIA_total=92, TP=46, TP_partial=44, FN=77, FP=2
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_41'
# Updated H2170_TOTAL_HER2_G0_2411_41: ref_total=327, MIA_total=257, TP=167, TP_partial=61, FN=99, FP=29
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_87'
# Updated H2170_HIGH_HER2_G1_2501_87: ref_total=477, MIA_total=185, TP=44, TP_partial=138, FN=295, FP=3
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_18'
# Updated H2170_HIGH_HER2_G0_2411_18: ref_total=413, MIA_total=177, TP=84, TP_partial=74, FN=255, FP=19
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_122'
# Updated H2170_TOTAL_HER2_G2_2502_122: ref_total=66, MIA_total=33, TP=21, TP_partial=8, FN=37, FP=4
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_1'
# Updated H2170_TOTAL_HER2_G0_2411_1: ref_total=272, MIA_total=86, TP=0, TP_partial=14, FN=258, FP=72
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_89'
# Updated H2170_HIGH_HER2_G0_2411_89: ref_total=107, MIA_total=61, TP=31, TP_partial=14, FN=62, FP=16
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_41'
# Updated H2170_HIGH_HER2_G2_2502_41: ref_total=206, MIA_total=167, TP=124, TP_partial=36, FN=46, FP=7
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_122'
# Updated H2170_HIGH_HER2_G0_2411_122: ref_total=109, MIA_total=60, TP=45, TP_partial=8, FN=56, FP=7
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_92'
# Updated H2170_TOTAL_HER2_G1_2501_92: ref_total=139, MIA_total=59, TP=28, TP_partial=30, FN=81, FP=1
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_83'
# Updated H2170_TOTAL_HER2_G1_2501_83: ref_total=399, MIA_total=109, TP=24, TP_partial=85, FN=290, FP=0
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_58'
# Updated H2170_LOW_HER2_G2_2502_58: ref_total=197, MIA_total=102, TP=68, TP_partial=25, FN=104, FP=9
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_26'
# Updated H2170_HIGH_HER2_G0_2411_26: ref_total=348, MIA_total=314, TP=127, TP_partial=139, FN=82, FP=48
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_42'
# Updated H2170_HIGH_HER2_G1_2501_42: ref_total=378, MIA_total=160, TP=63, TP_partial=94, FN=221, FP=3
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_79'
# Updated H2170_LOW_HER2_G0_2411_79: ref_total=98, MIA_total=45, TP=25, TP_partial=13, FN=60, FP=7
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_90'
# Updated H2170_TOTAL_HER2_G2_2502_90: ref_total=193, MIA_total=134, TP=81, TP_partial=43, FN=69, FP=10
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_122'
# Updated H2170_HIGH_HER2_G1_2501_122: ref_total=646, MIA_total=361, TP=108, TP_partial=235, FN=303, FP=18
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_54'
# Updated H2170_TOTAL_HER2_G0_2411_54: ref_total=811, MIA_total=491, TP=194, TP_partial=270, FN=347, FP=27
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_35'
# Updated H2170_TOTAL_HER2_G1_2501_35: ref_total=132, MIA_total=102, TP=56, TP_partial=37, FN=39, FP=9
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_99'
# Updated H2170_LOW_HER2_G0_2411_99: ref_total=212, MIA_total=29, TP=10, TP_partial=19, FN=183, FP=0
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_70'
# Updated H2170_TOTAL_HER2_G1_2501_70: ref_total=295, MIA_total=95, TP=30, TP_partial=62, FN=203, FP=3
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_34'
# Updated H2170_TOTAL_HER2_G1_2501_34: ref_total=160, MIA_total=64, TP=21, TP_partial=42, FN=97, FP=1
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_22'
# Updated H2170_TOTAL_HER2_G0_2411_22: ref_total=206, MIA_total=58, TP=13, TP_partial=41, FN=152, FP=4
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_81'
# Updated H2170_HIGH_HER2_G1_2501_81: ref_total=1152, MIA_total=829, TP=319, TP_partial=497, FN=336, FP=13
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_29'
# Updated H2170_LOW_HER2_G1_2501_29: ref_total=177, MIA_total=36, TP=20, TP_partial=12, FN=145, FP=4
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_49'
# Updated H2170_TOTAL_HER2_G2_2502_49: ref_total=248, MIA_total=184, TP=115, TP_partial=65, FN=68, FP=4
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_67'
# Updated H2170_LOW_HER2_G1_2501_67: ref_total=190, MIA_total=63, TP=29, TP_partial=28, FN=133, FP=6
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_5'
# Updated H2170_LOW_HER2_G2_2502_5: ref_total=81, MIA_total=217, TP=3, TP_partial=24, FN=54, FP=190
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_99'
# Updated H2170_HIGH_HER2_G2_2502_99: ref_total=441, MIA_total=193, TP=49, TP_partial=140, FN=252, FP=4
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_58'
# Updated H2170_TOTAL_HER2_G1_2501_58: ref_total=284, MIA_total=78, TP=12, TP_partial=60, FN=212, FP=6
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_36'
# Updated H2170_LOW_HER2_G0_2411_36: ref_total=229, MIA_total=29, TP=12, TP_partial=16, FN=201, FP=1
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_97'
# Updated H2170_TOTAL_HER2_G0_2411_97: ref_total=415, MIA_total=206, TP=126, TP_partial=61, FN=228, FP=19
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_127'
# Updated H2170_TOTAL_HER2_G2_2502_127: ref_total=116, MIA_total=81, TP=62, TP_partial=15, FN=39, FP=4
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_116'
# Updated H2170_HIGH_HER2_G0_2411_116: ref_total=862, MIA_total=453, TP=168, TP_partial=267, FN=427, FP=18
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_38'
# Updated H2170_TOTAL_HER2_G1_2501_38: ref_total=230, MIA_total=114, TP=29, TP_partial=81, FN=120, FP=4
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_54'
# Updated H2170_HIGH_HER2_G0_2411_54: ref_total=373, MIA_total=271, TP=164, TP_partial=55, FN=154, FP=52
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_61'
# Updated H2170_LOW_HER2_G0_2411_61: ref_total=150, MIA_total=119, TP=37, TP_partial=31, FN=82, FP=51
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_82'
# Updated H2170_LOW_HER2_G0_2411_82: ref_total=57, MIA_total=38, TP=19, TP_partial=6, FN=32, FP=13
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_85'
# Updated H2170_HIGH_HER2_G0_2411_85: ref_total=192, MIA_total=155, TP=72, TP_partial=36, FN=84, FP=47
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_89'
# Updated H2170_HIGH_HER2_G1_2501_89: ref_total=404, MIA_total=288, TP=114, TP_partial=149, FN=141, FP=25
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_64'
# Updated H2170_TOTAL_HER2_G0_2411_64: ref_total=200, MIA_total=101, TP=59, TP_partial=26, FN=115, FP=16
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_68'
# Updated H2170_TOTAL_HER2_G1_2501_68: ref_total=306, MIA_total=212, TP=61, TP_partial=139, FN=106, FP=12
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_123'
# Updated H2170_HIGH_HER2_G1_2501_123: ref_total=118, MIA_total=80, TP=52, TP_partial=25, FN=41, FP=3
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_60'
# Updated H2170_HIGH_HER2_G2_2502_60: ref_total=737, MIA_total=279, TP=87, TP_partial=178, FN=472, FP=14
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_59'
# Updated H2170_LOW_HER2_G2_2502_59: ref_total=147, MIA_total=60, TP=29, TP_partial=25, FN=93, FP=6
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_125'
# Updated H2170_HIGH_HER2_G1_2501_125: ref_total=859, MIA_total=575, TP=188, TP_partial=373, FN=298, FP=14
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_34'
# Updated H2170_HIGH_HER2_G2_2502_34: ref_total=94, MIA_total=71, TP=39, TP_partial=26, FN=29, FP=6
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_89'
# Updated H2170_TOTAL_HER2_G0_2411_89: ref_total=481, MIA_total=90, TP=48, TP_partial=39, FN=394, FP=3
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_86'
# Updated H2170_HIGH_HER2_G1_2501_86: ref_total=171, MIA_total=77, TP=39, TP_partial=37, FN=95, FP=1
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_116'
# Updated H2170_TOTAL_HER2_G2_2502_116: ref_total=226, MIA_total=173, TP=102, TP_partial=67, FN=57, FP=4
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_78'
# Updated H2170_TOTAL_HER2_G1_2501_78: ref_total=463, MIA_total=238, TP=57, TP_partial=174, FN=232, FP=7
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_14'
# Updated H2170_HIGH_HER2_G1_2501_14: ref_total=278, MIA_total=97, TP=48, TP_partial=42, FN=188, FP=7
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_77'
# Updated H2170_HIGH_HER2_G0_2411_77: ref_total=442, MIA_total=230, TP=126, TP_partial=96, FN=220, FP=8
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_8'
# Updated H2170_LOW_HER2_G0_2411_8: ref_total=259, MIA_total=80, TP=2, TP_partial=23, FN=234, FP=55
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_84'
# Updated H2170_HIGH_HER2_G0_2411_84: ref_total=288, MIA_total=87, TP=44, TP_partial=42, FN=202, FP=1
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_99'
# Updated H2170_HIGH_HER2_G1_2501_99: ref_total=360, MIA_total=205, TP=79, TP_partial=117, FN=164, FP=9
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_68'
# Updated H2170_HIGH_HER2_G2_2502_68: ref_total=99, MIA_total=150, TP=43, TP_partial=28, FN=28, FP=79
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_95'
# Updated H2170_LOW_HER2_G1_2501_95: ref_total=204, MIA_total=33, TP=3, TP_partial=27, FN=174, FP=3
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_41'
# Updated H2170_LOW_HER2_G1_2501_41: ref_total=69, MIA_total=39, TP=18, TP_partial=12, FN=39, FP=9
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_84'
# Updated H2170_TOTAL_HER2_G1_2501_84: ref_total=178, MIA_total=27, TP=4, TP_partial=16, FN=158, FP=7
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_7'
# Updated H2170_LOW_HER2_G2_2502_7: ref_total=174, MIA_total=40, TP=0, TP_partial=23, FN=151, FP=17
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_110'
# Updated H2170_HIGH_HER2_G0_2411_110: ref_total=237, MIA_total=108, TP=67, TP_partial=34, FN=136, FP=7
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_80'
# Updated H2170_HIGH_HER2_G0_2411_80: ref_total=197, MIA_total=112, TP=82, TP_partial=24, FN=91, FP=6
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_2'
# Updated H2170_LOW_HER2_G2_2502_2: ref_total=134, MIA_total=47, TP=3, TP_partial=21, FN=110, FP=23
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_87'
# Updated H2170_TOTAL_HER2_G0_2411_87: ref_total=570, MIA_total=291, TP=102, TP_partial=181, FN=287, FP=8
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_31'
# Updated H2170_TOTAL_HER2_G0_2411_31: ref_total=464, MIA_total=283, TP=126, TP_partial=149, FN=189, FP=8
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_30'
# Updated H2170_LOW_HER2_G1_2501_30: ref_total=404, MIA_total=36, TP=2, TP_partial=34, FN=368, FP=0
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_99'
# Updated H2170_TOTAL_HER2_G2_2502_99: ref_total=303, MIA_total=103, TP=31, TP_partial=72, FN=200, FP=0
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_29'
# Updated H2170_TOTAL_HER2_G0_2411_29: ref_total=414, MIA_total=309, TP=125, TP_partial=145, FN=144, FP=39
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_68'
# Updated H2170_TOTAL_HER2_G0_2411_68: ref_total=367, MIA_total=193, TP=113, TP_partial=74, FN=180, FP=6
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_64'
# Updated H2170_HIGH_HER2_G0_2411_64: ref_total=469, MIA_total=221, TP=108, TP_partial=86, FN=275, FP=27
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_65'
# Updated H2170_TOTAL_HER2_G1_2501_65: ref_total=204, MIA_total=32, TP=4, TP_partial=27, FN=173, FP=1
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_58'
# Updated H2170_LOW_HER2_G1_2501_58: ref_total=299, MIA_total=101, TP=24, TP_partial=77, FN=198, FP=0
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_61'
# Updated H2170_TOTAL_HER2_G2_2502_61: ref_total=166, MIA_total=96, TP=57, TP_partial=36, FN=73, FP=3
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_116'
# Updated H2170_HIGH_HER2_G1_2501_116: ref_total=162, MIA_total=116, TP=82, TP_partial=32, FN=48, FP=2
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_118'
# Updated H2170_TOTAL_HER2_G2_2502_118: ref_total=206, MIA_total=127, TP=47, TP_partial=71, FN=88, FP=9
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_128D'
# Updated H2170_TOTAL_HER2_G0_2411_128D: ref_total=330, MIA_total=8, TP=4, TP_partial=4, FN=322, FP=0
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_127'
# Updated H2170_TOTAL_HER2_G1_2501_127: ref_total=92, MIA_total=6, TP=2, TP_partial=4, FN=86, FP=0
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_90'
# Updated H2170_TOTAL_HER2_G1_2501_90: ref_total=371, MIA_total=285, TP=116, TP_partial=151, FN=104, FP=18
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_94'
# Updated H2170_HIGH_HER2_G1_2501_94: ref_total=365, MIA_total=159, TP=69, TP_partial=89, FN=207, FP=1
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_9'
# Updated H2170_LOW_HER2_G2_2502_9: ref_total=151, MIA_total=56, TP=1, TP_partial=16, FN=134, FP=39
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_57'
# Updated H2170_LOW_HER2_G1_2501_57: ref_total=68, MIA_total=10, TP=1, TP_partial=8, FN=59, FP=1
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_98'
# Updated H2170_TOTAL_HER2_G1_2501_98: ref_total=226, MIA_total=95, TP=23, TP_partial=72, FN=131, FP=0
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_112'
# Updated H2170_LOW_HER2_G1_2501_112: ref_total=374, MIA_total=68, TP=15, TP_partial=53, FN=306, FP=0
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_99'
# Updated H2170_HIGH_HER2_G0_2411_99: ref_total=592, MIA_total=225, TP=104, TP_partial=114, FN=374, FP=7
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_100'
# Updated H2170_TOTAL_HER2_G0_2411_100: ref_total=330, MIA_total=33, TP=16, TP_partial=17, FN=297, FP=0
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_68'
# Updated H2170_LOW_HER2_G2_2502_68: ref_total=269, MIA_total=226, TP=138, TP_partial=81, FN=50, FP=7
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_45'
# Updated H2170_HIGH_HER2_G1_2501_45: ref_total=228, MIA_total=134, TP=72, TP_partial=56, FN=100, FP=6
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_28B'
# Updated H2170_LOW_HER2_G2_2502_28B: ref_total=284, MIA_total=150, TP=57, TP_partial=88, FN=139, FP=5
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_117'
# Updated H2170_HIGH_HER2_G2_2502_117: ref_total=174, MIA_total=62, TP=35, TP_partial=26, FN=113, FP=1
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_84'
# Updated H2170_LOW_HER2_G1_2501_84: ref_total=161, MIA_total=58, TP=19, TP_partial=38, FN=104, FP=1
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_110'
# Updated H2170_TOTAL_HER2_G0_2411_110: ref_total=496, MIA_total=233, TP=137, TP_partial=92, FN=267, FP=4
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_112'
# Updated H2170_HIGH_HER2_G1_2501_112: ref_total=353, MIA_total=199, TP=113, TP_partial=74, FN=166, FP=12
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_33'
# Updated H2170_LOW_HER2_G0_2411_33: ref_total=239, MIA_total=146, TP=51, TP_partial=57, FN=131, FP=38
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_83'
# Updated H2170_HIGH_HER2_G1_2501_83: ref_total=602, MIA_total=122, TP=39, TP_partial=82, FN=481, FP=1
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_129'
# Updated H2170_HIGH_HER2_G1_2501_129: ref_total=133, MIA_total=68, TP=33, TP_partial=32, FN=68, FP=3
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_54'
# Updated H2170_TOTAL_HER2_G1_2501_54: ref_total=181, MIA_total=94, TP=38, TP_partial=53, FN=90, FP=3
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_70'
# Updated H2170_HIGH_HER2_G0_2411_70: ref_total=421, MIA_total=186, TP=61, TP_partial=100, FN=260, FP=25
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_5'
# Updated H2170_HIGH_HER2_G0_2411_5: ref_total=216, MIA_total=268, TP=3, TP_partial=38, FN=175, FP=227
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_8'
# Updated H2170_LOW_HER2_G1_2501_8: ref_total=162, MIA_total=60, TP=5, TP_partial=28, FN=129, FP=27
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_88'
# Updated H2170_TOTAL_HER2_G0_2411_88: ref_total=477, MIA_total=344, TP=130, TP_partial=185, FN=162, FP=29
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_65'
# Updated H2170_HIGH_HER2_G1_2501_65: ref_total=113, MIA_total=73, TP=55, TP_partial=12, FN=46, FP=6
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_16'
# Updated H2170_HIGH_HER2_G2_2502_16: ref_total=495, MIA_total=238, TP=81, TP_partial=151, FN=263, FP=6
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_34'
# Updated H2170_LOW_HER2_G2_2502_34: ref_total=286, MIA_total=205, TP=100, TP_partial=94, FN=92, FP=11
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_112A'
# Updated H2170_TOTAL_HER2_G0_2411_112A: ref_total=605, MIA_total=334, TP=202, TP_partial=123, FN=280, FP=9
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_101'
# Updated H2170_HIGH_HER2_G0_2411_101: ref_total=575, MIA_total=331, TP=184, TP_partial=132, FN=259, FP=15
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_37'
# Updated H2170_TOTAL_HER2_G2_2502_37: ref_total=100, MIA_total=78, TP=46, TP_partial=24, FN=30, FP=8
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_75A'
# Updated H2170_HIGH_HER2_G2_2502_75A: ref_total=307, MIA_total=31, TP=9, TP_partial=21, FN=277, FP=1
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_9B'
# Updated H2170_HIGH_HER2_G1_2501_9B: ref_total=775, MIA_total=137, TP=17, TP_partial=119, FN=639, FP=1
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_72'
# Updated H2170_LOW_HER2_G2_2502_72: ref_total=220, MIA_total=107, TP=51, TP_partial=50, FN=119, FP=6
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_119'
# Updated H2170_TOTAL_HER2_G0_2411_119: ref_total=270, MIA_total=34, TP=24, TP_partial=9, FN=237, FP=1
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_103'
# Updated H2170_HIGH_HER2_G0_2411_103: ref_total=337, MIA_total=95, TP=38, TP_partial=49, FN=250, FP=8
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_14'
# Updated H2170_TOTAL_HER2_G0_2411_14: ref_total=344, MIA_total=133, TP=77, TP_partial=51, FN=216, FP=5
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_30'
# Updated H2170_LOW_HER2_G0_2411_30: ref_total=179, MIA_total=35, TP=13, TP_partial=18, FN=148, FP=4
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_21'
# Updated H2170_TOTAL_HER2_G2_2502_21: ref_total=390, MIA_total=153, TP=22, TP_partial=119, FN=249, FP=12
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_84'
# Updated H2170_HIGH_HER2_G1_2501_84: ref_total=596, MIA_total=109, TP=39, TP_partial=69, FN=488, FP=1
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_9'
# Updated H2170_HIGH_HER2_G2_2502_9: ref_total=157, MIA_total=219, TP=7, TP_partial=70, FN=80, FP=142
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_21'
# Updated H2170_LOW_HER2_G0_2411_21: ref_total=64, MIA_total=18, TP=2, TP_partial=5, FN=57, FP=11
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_9'
# Updated H2170_LOW_HER2_G0_2411_9: ref_total=64, MIA_total=50, TP=0, TP_partial=6, FN=58, FP=44
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_105'
# Updated H2170_LOW_HER2_G2_2502_105: ref_total=172, MIA_total=125, TP=91, TP_partial=24, FN=57, FP=10
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_121'
# Updated H2170_TOTAL_HER2_G2_2502_121: ref_total=150, MIA_total=57, TP=15, TP_partial=42, FN=93, FP=0
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_21A'
# Updated H2170_LOW_HER2_G1_2501_21A: ref_total=111, MIA_total=32, TP=11, TP_partial=18, FN=82, FP=3
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_56'
# Updated H2170_LOW_HER2_G1_2501_56: ref_total=219, MIA_total=20, TP=4, TP_partial=16, FN=199, FP=0
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_48'
# Updated H2170_TOTAL_HER2_G0_2411_48: ref_total=218, MIA_total=52, TP=35, TP_partial=14, FN=169, FP=3
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_36'
# Updated H2170_HIGH_HER2_G2_2502_36: ref_total=106, MIA_total=82, TP=65, TP_partial=10, FN=31, FP=7
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_1'
# Updated H2170_HIGH_HER2_G2_2502_1: ref_total=222, MIA_total=27, TP=0, TP_partial=15, FN=207, FP=12
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_117'
# Updated H2170_HIGH_HER2_G0_2411_117: ref_total=242, MIA_total=91, TP=47, TP_partial=28, FN=167, FP=16
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_37'
# Updated H2170_TOTAL_HER2_G0_2411_37: ref_total=281, MIA_total=70, TP=39, TP_partial=14, FN=228, FP=17
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_101'
# Updated H2170_HIGH_HER2_G2_2502_101: ref_total=273, MIA_total=201, TP=114, TP_partial=79, FN=80, FP=8
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_37'
# Updated H2170_TOTAL_HER2_G1_2501_37: ref_total=193, MIA_total=22, TP=8, TP_partial=13, FN=172, FP=1
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_21'
# Updated H2170_TOTAL_HER2_G0_2411_21: ref_total=852, MIA_total=580, TP=361, TP_partial=195, FN=296, FP=24
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_36'
# Updated H2170_LOW_HER2_G2_2502_36: ref_total=419, MIA_total=229, TP=77, TP_partial=142, FN=200, FP=10
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_18'
# Updated H2170_HIGH_HER2_G1_2501_18: ref_total=579, MIA_total=85, TP=34, TP_partial=47, FN=498, FP=4
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_81'
# Updated H2170_LOW_HER2_G0_2411_81: ref_total=187, MIA_total=58, TP=16, TP_partial=31, FN=140, FP=11
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_91'
# Updated H2170_TOTAL_HER2_G0_2411_91: ref_total=197, MIA_total=115, TP=55, TP_partial=45, FN=97, FP=15
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_5'
# Updated H2170_LOW_HER2_G0_2411_5: ref_total=334, MIA_total=45, TP=1, TP_partial=21, FN=312, FP=23
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_31'
# Updated H2170_HIGH_HER2_G0_2411_31: ref_total=180, MIA_total=75, TP=39, TP_partial=29, FN=112, FP=7
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_106'
# Updated H2170_LOW_HER2_G1_2501_106: ref_total=108, MIA_total=24, TP=14, TP_partial=10, FN=84, FP=0
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_24'
# Updated H2170_HIGH_HER2_G0_2411_24: ref_total=478, MIA_total=175, TP=70, TP_partial=100, FN=308, FP=5
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_7'
# Updated H2170_LOW_HER2_G0_2411_7: ref_total=129, MIA_total=5, TP=0, TP_partial=0, FN=129, FP=5
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_128C'
# Updated H2170_TOTAL_HER2_G0_2411_128C: ref_total=279, MIA_total=51, TP=16, TP_partial=32, FN=231, FP=3
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_126'
# Updated H2170_TOTAL_HER2_G0_2411_126: ref_total=332, MIA_total=244, TP=146, TP_partial=58, FN=128, FP=40
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_16'
# Updated H2170_LOW_HER2_G2_2502_16: ref_total=228, MIA_total=198, TP=131, TP_partial=54, FN=43, FP=13
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_66'
# Updated H2170_LOW_HER2_G1_2501_66: ref_total=65, MIA_total=28, TP=14, TP_partial=9, FN=42, FP=5
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_19'
# Updated H2170_HIGH_HER2_G0_2411_19: ref_total=342, MIA_total=251, TP=92, TP_partial=62, FN=188, FP=97
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_28'
# Updated H2170_TOTAL_HER2_G0_2411_28: ref_total=241, MIA_total=67, TP=23, TP_partial=41, FN=177, FP=3
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_98'
# Updated H2170_LOW_HER2_G1_2501_98: ref_total=79, MIA_total=16, TP=3, TP_partial=8, FN=68, FP=5
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_94'
# Updated H2170_LOW_HER2_G0_2411_94: ref_total=450, MIA_total=365, TP=206, TP_partial=133, FN=111, FP=26
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_95'
# Updated H2170_TOTAL_HER2_G0_2411_95: ref_total=355, MIA_total=81, TP=43, TP_partial=36, FN=276, FP=2
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_76'
# Updated H2170_HIGH_HER2_G1_2501_76: ref_total=303, MIA_total=161, TP=61, TP_partial=99, FN=143, FP=1
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_97'
# Updated H2170_LOW_HER2_G0_2411_97: ref_total=152, MIA_total=31, TP=19, TP_partial=12, FN=121, FP=0
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_123'
# Updated H2170_TOTAL_HER2_G1_2501_123: ref_total=252, MIA_total=123, TP=56, TP_partial=65, FN=131, FP=2
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_117'
# Updated H2170_LOW_HER2_G2_2502_117: ref_total=372, MIA_total=95, TP=25, TP_partial=68, FN=279, FP=2
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_125'
# Updated H2170_HIGH_HER2_G2_2502_125: ref_total=199, MIA_total=127, TP=77, TP_partial=38, FN=84, FP=12
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_56'
# Updated H2170_TOTAL_HER2_G1_2501_56: ref_total=157, MIA_total=72, TP=41, TP_partial=27, FN=89, FP=4
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_75'
# Updated H2170_LOW_HER2_G2_2502_75: ref_total=125, MIA_total=19, TP=14, TP_partial=5, FN=106, FP=0
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_74'
# Updated H2170_HIGH_HER2_G2_2502_74: ref_total=421, MIA_total=37, TP=8, TP_partial=25, FN=388, FP=4
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_110'
# Updated H2170_TOTAL_HER2_G1_2501_110: ref_total=163, MIA_total=66, TP=28, TP_partial=35, FN=100, FP=3
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_51'
# Updated H2170_HIGH_HER2_G0_2411_51: ref_total=458, MIA_total=190, TP=103, TP_partial=79, FN=276, FP=8
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_13'
# Updated H2170_HIGH_HER2_G2_2502_13: ref_total=197, MIA_total=137, TP=77, TP_partial=52, FN=68, FP=8
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_17'
# Updated H2170_LOW_HER2_G2_2502_17: ref_total=332, MIA_total=160, TP=76, TP_partial=78, FN=178, FP=6
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_80'
# Updated H2170_LOW_HER2_G1_2501_80: ref_total=33, MIA_total=12, TP=4, TP_partial=6, FN=23, FP=2
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_62'
# Updated H2170_TOTAL_HER2_G1_2501_62: ref_total=152, MIA_total=84, TP=35, TP_partial=42, FN=75, FP=7
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_5'
# Updated H2170_HIGH_HER2_G2_2502_5: ref_total=427, MIA_total=297, TP=18, TP_partial=147, FN=262, FP=132
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_72B'
# Updated H2170_TOTAL_HER2_G1_2501_72B: ref_total=443, MIA_total=234, TP=84, TP_partial=148, FN=211, FP=2
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_57'
# Updated H2170_LOW_HER2_G0_2411_57: ref_total=105, MIA_total=27, TP=9, TP_partial=11, FN=85, FP=7
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_73'
# Updated H2170_TOTAL_HER2_G2_2502_73: ref_total=229, MIA_total=118, TP=52, TP_partial=64, FN=113, FP=2
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_111A'
# Updated H2170_LOW_HER2_G2_2502_111A: ref_total=193, MIA_total=60, TP=10, TP_partial=49, FN=134, FP=1
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_42'
# Updated H2170_HIGH_HER2_G0_2411_42: ref_total=466, MIA_total=244, TP=107, TP_partial=86, FN=273, FP=51
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_52'
# Updated H2170_LOW_HER2_G2_2502_52: ref_total=246, MIA_total=142, TP=46, TP_partial=76, FN=124, FP=20
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_88'
# Updated H2170_TOTAL_HER2_G2_2502_88: ref_total=167, MIA_total=132, TP=91, TP_partial=29, FN=47, FP=12
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_48'
# Updated H2170_LOW_HER2_G1_2501_48: ref_total=128, MIA_total=76, TP=33, TP_partial=35, FN=60, FP=8
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_104'
# Updated H2170_LOW_HER2_G2_2502_104: ref_total=499, MIA_total=250, TP=64, TP_partial=176, FN=259, FP=10
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_88'
# Updated H2170_LOW_HER2_G0_2411_88: ref_total=212, MIA_total=161, TP=40, TP_partial=77, FN=95, FP=44
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_4'
# Updated H2170_HIGH_HER2_G1_2501_4: ref_total=363, MIA_total=59, TP=1, TP_partial=29, FN=333, FP=29
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_47'
# Updated H2170_HIGH_HER2_G2_2502_47: ref_total=416, MIA_total=291, TP=111, TP_partial=168, FN=137, FP=12
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_21'
# Updated H2170_HIGH_HER2_G2_2502_21: ref_total=577, MIA_total=177, TP=42, TP_partial=135, FN=400, FP=0
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_9'
# Updated H2170_TOTAL_HER2_G1_2501_9: ref_total=225, MIA_total=59, TP=2, TP_partial=37, FN=186, FP=20
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_70'
# Updated H2170_TOTAL_HER2_G2_2502_70: ref_total=114, MIA_total=92, TP=77, TP_partial=9, FN=28, FP=6
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_108'
# Updated H2170_HIGH_HER2_G2_2502_108: ref_total=183, MIA_total=167, TP=141, TP_partial=20, FN=22, FP=6
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_89'
# Updated H2170_TOTAL_HER2_G2_2502_89: ref_total=221, MIA_total=167, TP=66, TP_partial=85, FN=70, FP=16
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_10'
# ...
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_71'
# Updated H2170_LOW_HER2_G1_2501_71: ref_total=155, MIA_total=82, TP=33, TP_partial=44, FN=78, FP=5
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_89'
# Updated H2170_LOW_HER2_G1_2501_89: ref_total=118, MIA_total=21, TP=8, TP_partial=9, FN=101, FP=4
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_29'
# Updated H2170_HIGH_HER2_G1_2501_29: ref_total=629, MIA_total=307, TP=132, TP_partial=167, FN=330, FP=8
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_123'
# Updated H2170_LOW_HER2_G0_2411_123: ref_total=50, MIA_total=19, TP=9, TP_partial=4, FN=37, FP=6
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_72'
# Updated H2170_LOW_HER2_G1_2501_72: ref_total=147, MIA_total=41, TP=15, TP_partial=23, FN=109, FP=3
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_3'
# Updated H2170_LOW_HER2_G0_2411_3: ref_total=173, MIA_total=36, TP=0, TP_partial=11, FN=162, FP=25
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_25'
# Updated H2170_TOTAL_HER2_G1_2501_25: ref_total=264, MIA_total=96, TP=43, TP_partial=53, FN=168, FP=0
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_74'
# Updated H2170_LOW_HER2_G1_2501_74: ref_total=255, MIA_total=33, TP=7, TP_partial=25, FN=223, FP=1
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_60'
# Updated H2170_HIGH_HER2_G0_2411_60: ref_total=623, MIA_total=398, TP=209, TP_partial=165, FN=249, FP=24
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_37'
# Updated H2170_HIGH_HER2_G2_2502_37: ref_total=193, MIA_total=164, TP=116, TP_partial=36, FN=41, FP=12
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_46'
# Updated H2170_LOW_HER2_G1_2501_46: ref_total=52, MIA_total=7, TP=1, TP_partial=5, FN=46, FP=1
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_78'
# Updated H2170_LOW_HER2_G1_2501_78: ref_total=156, MIA_total=17, TP=1, TP_partial=13, FN=142, FP=3
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_65'
# Updated H2170_TOTAL_HER2_G0_2411_65: ref_total=296, MIA_total=229, TP=146, TP_partial=59, FN=91, FP=24
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_124'
# Updated H2170_HIGH_HER2_G1_2501_124: ref_total=518, MIA_total=255, TP=83, TP_partial=167, FN=268, FP=5
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_11'
# Updated H2170_TOTAL_HER2_G0_2411_11: ref_total=340, MIA_total=121, TP=1, TP_partial=24, FN=315, FP=96
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_44'
# Updated H2170_LOW_HER2_G0_2411_44: ref_total=55, MIA_total=4, TP=2, TP_partial=1, FN=52, FP=1
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_43B'
# Updated H2170_TOTAL_HER2_G2_2502_43B: ref_total=202, MIA_total=15, TP=5, TP_partial=8, FN=189, FP=2
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_33'
# Updated H2170_TOTAL_HER2_G0_2411_33: ref_total=392, MIA_total=67, TP=34, TP_partial=30, FN=328, FP=3
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_126'
# Updated H2170_HIGH_HER2_G1_2501_126: ref_total=316, MIA_total=117, TP=44, TP_partial=73, FN=199, FP=0
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_119'
# Updated H2170_HIGH_HER2_G0_2411_119: ref_total=218, MIA_total=104, TP=79, TP_partial=22, FN=117, FP=3
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_28B'
# Updated H2170_TOTAL_HER2_G1_2501_28B: ref_total=207, MIA_total=35, TP=10, TP_partial=24, FN=173, FP=1
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_25'
# Updated H2170_TOTAL_HER2_G2_2502_25: ref_total=275, MIA_total=176, TP=82, TP_partial=76, FN=117, FP=18
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_23'
# Updated H2170_LOW_HER2_G1_2501_23: ref_total=135, MIA_total=26, TP=4, TP_partial=19, FN=112, FP=3
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_59'
# Updated H2170_LOW_HER2_G1_2501_59: ref_total=247, MIA_total=73, TP=27, TP_partial=41, FN=179, FP=5
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_60'
# Updated H2170_TOTAL_HER2_G1_2501_60: ref_total=215, MIA_total=33, TP=6, TP_partial=26, FN=183, FP=1
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_71A'
# Updated H2170_LOW_HER2_G0_2411_71A: ref_total=90, MIA_total=51, TP=4, TP_partial=16, FN=70, FP=31
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_82'
# Updated H2170_HIGH_HER2_G0_2411_82: ref_total=349, MIA_total=128, TP=77, TP_partial=49, FN=223, FP=2
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_108'
# Updated H2170_LOW_HER2_G1_2501_108: ref_total=73, MIA_total=75, TP=24, TP_partial=23, FN=26, FP=28
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_58'
# Updated H2170_HIGH_HER2_G2_2502_58: ref_total=211, MIA_total=131, TP=68, TP_partial=58, FN=85, FP=5
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_45'
# Updated H2170_LOW_HER2_G0_2411_45: ref_total=136, MIA_total=34, TP=17, TP_partial=13, FN=106, FP=4
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_60'
# Updated H2170_TOTAL_HER2_G0_2411_60: ref_total=311, MIA_total=164, TP=68, TP_partial=72, FN=171, FP=24
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_74'
# Updated H2170_TOTAL_HER2_G2_2502_74: ref_total=397, MIA_total=328, TP=177, TP_partial=142, FN=78, FP=9
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_109'
# Updated H2170_HIGH_HER2_G0_2411_109: ref_total=324, MIA_total=168, TP=135, TP_partial=23, FN=166, FP=10
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_129'
# Updated H2170_HIGH_HER2_G2_2502_129: ref_total=168, MIA_total=88, TP=54, TP_partial=32, FN=82, FP=2
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_80'
# Updated H2170_HIGH_HER2_G1_2501_80: ref_total=629, MIA_total=142, TP=15, TP_partial=127, FN=487, FP=0
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_112B'
# Updated H2170_TOTAL_HER2_G0_2411_112B: ref_total=550, MIA_total=136, TP=84, TP_partial=50, FN=416, FP=2
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_2'
# Updated H2170_HIGH_HER2_G1_2501_2: ref_total=203, MIA_total=49, TP=1, TP_partial=16, FN=186, FP=32
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_9'
# Updated H2170_TOTAL_HER2_G2_2502_9: ref_total=95, MIA_total=80, TP=0, TP_partial=23, FN=72, FP=57
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_8'
# Updated H2170_HIGH_HER2_G2_2502_8: ref_total=247, MIA_total=44, TP=1, TP_partial=23, FN=223, FP=20
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_30'
# Updated H2170_HIGH_HER2_G1_2501_30: ref_total=94, MIA_total=48, TP=33, TP_partial=11, FN=50, FP=4
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_6'
# Updated H2170_TOTAL_HER2_G2_2502_6: ref_total=235, MIA_total=109, TP=5, TP_partial=44, FN=186, FP=60
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_8'
# Updated H2170_HIGH_HER2_G0_2411_8: ref_total=313, MIA_total=61, TP=2, TP_partial=28, FN=283, FP=31
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_14B'
# Updated H2170_LOW_HER2_G1_2501_14B: ref_total=212, MIA_total=26, TP=3, TP_partial=23, FN=186, FP=0
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_30'
# Updated H2170_TOTAL_HER2_G2_2502_30: ref_total=221, MIA_total=90, TP=35, TP_partial=53, FN=133, FP=2
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_124'
# Updated H2170_HIGH_HER2_G0_2411_124: ref_total=226, MIA_total=79, TP=42, TP_partial=26, FN=158, FP=11
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_127'
# Updated H2170_HIGH_HER2_G0_2411_127: ref_total=151, MIA_total=88, TP=55, TP_partial=25, FN=71, FP=8
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_86'
# Updated H2170_LOW_HER2_G1_2501_86: ref_total=74, MIA_total=30, TP=14, TP_partial=13, FN=47, FP=3
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_15'
# Updated H2170_TOTAL_HER2_G2_2502_15: ref_total=167, MIA_total=130, TP=82, TP_partial=38, FN=47, FP=10
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_75'
# Updated H2170_HIGH_HER2_G0_2411_75: ref_total=346, MIA_total=195, TP=129, TP_partial=57, FN=160, FP=9
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_38'
# Updated H2170_TOTAL_HER2_G2_2502_38: ref_total=52, MIA_total=35, TP=21, TP_partial=8, FN=23, FP=6
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_48'
# Updated H2170_LOW_HER2_G2_2502_48: ref_total=445, MIA_total=222, TP=64, TP_partial=155, FN=226, FP=3
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_95'
# Updated H2170_LOW_HER2_G0_2411_95: ref_total=300, MIA_total=212, TP=130, TP_partial=69, FN=101, FP=13
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_118'
# Updated H2170_LOW_HER2_G0_2411_118: ref_total=161, MIA_total=108, TP=65, TP_partial=30, FN=66, FP=13
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_96'
# Updated H2170_HIGH_HER2_G2_2502_96: ref_total=642, MIA_total=402, TP=163, TP_partial=225, FN=254, FP=14
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_48'
# Updated H2170_HIGH_HER2_G1_2501_48: ref_total=329, MIA_total=230, TP=100, TP_partial=118, FN=111, FP=12
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_88'
# Updated H2170_LOW_HER2_G2_2502_88: ref_total=425, MIA_total=137, TP=39, TP_partial=92, FN=294, FP=6
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_1'
# Updated H2170_LOW_HER2_G0_2411_1: ref_total=201, MIA_total=47, TP=2, TP_partial=18, FN=181, FP=27
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_120'
# Updated H2170_LOW_HER2_G0_2411_120: ref_total=95, MIA_total=15, TP=7, TP_partial=5, FN=83, FP=3
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_56'
# Updated H2170_LOW_HER2_G2_2502_56: ref_total=349, MIA_total=89, TP=16, TP_partial=71, FN=262, FP=2
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_109'
# Updated H2170_TOTAL_HER2_G0_2411_109: ref_total=404, MIA_total=141, TP=61, TP_partial=79, FN=264, FP=1
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_28C'
# Updated H2170_LOW_HER2_G2_2502_28C: ref_total=262, MIA_total=41, TP=14, TP_partial=27, FN=221, FP=0
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_66'
# Updated H2170_LOW_HER2_G0_2411_66: ref_total=165, MIA_total=29, TP=11, TP_partial=11, FN=143, FP=7
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_102'
# Updated H2170_TOTAL_HER2_G2_2502_102: ref_total=86, MIA_total=64, TP=36, TP_partial=22, FN=28, FP=6
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_122'
# Updated H2170_LOW_HER2_G2_2502_122: ref_total=598, MIA_total=367, TP=194, TP_partial=171, FN=233, FP=2
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_30'
# Updated H2170_HIGH_HER2_G2_2502_30: ref_total=227, MIA_total=151, TP=73, TP_partial=76, FN=78, FP=2
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_15'
# Updated H2170_HIGH_HER2_G0_2411_15: ref_total=411, MIA_total=145, TP=67, TP_partial=76, FN=268, FP=2
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_30'
# Updated H2170_TOTAL_HER2_G1_2501_30: ref_total=88, MIA_total=59, TP=37, TP_partial=20, FN=31, FP=2
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_11'
# Updated H2170_TOTAL_HER2_G1_2501_11: ref_total=180, MIA_total=54, TP=3, TP_partial=32, FN=145, FP=19
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_68'
# Updated H2170_HIGH_HER2_G0_2411_68: ref_total=349, MIA_total=62, TP=29, TP_partial=32, FN=288, FP=1
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_67'
# Updated H2170_HIGH_HER2_G0_2411_67: ref_total=274, MIA_total=171, TP=107, TP_partial=40, FN=127, FP=24
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_16'
# Updated H2170_HIGH_HER2_G0_2411_16: ref_total=315, MIA_total=117, TP=66, TP_partial=46, FN=203, FP=5
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_6'
# Updated H2170_LOW_HER2_G0_2411_6: ref_total=83, MIA_total=119, TP=0, TP_partial=10, FN=73, FP=109
# Processing unique_id: 'H2170_LOW_HER2_G1_2501_113'
# Updated H2170_LOW_HER2_G1_2501_113: ref_total=134, MIA_total=40, TP=17, TP_partial=17, FN=100, FP=6
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_86'
# Updated H2170_HIGH_HER2_G2_2502_86: ref_total=276, MIA_total=107, TP=47, TP_partial=56, FN=173, FP=4
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_125'
# Updated H2170_TOTAL_HER2_G1_2501_125: ref_total=145, MIA_total=30, TP=9, TP_partial=20, FN=116, FP=1
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_51'
# Updated H2170_TOTAL_HER2_G1_2501_51: ref_total=235, MIA_total=95, TP=22, TP_partial=71, FN=142, FP=2
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_5'
# Updated H2170_TOTAL_HER2_G0_2411_5: ref_total=154, MIA_total=114, TP=2, TP_partial=36, FN=116, FP=76
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_41'
# Updated H2170_TOTAL_HER2_G2_2502_41: ref_total=137, MIA_total=30, TP=17, TP_partial=13, FN=107, FP=0
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_106'
# Updated H2170_HIGH_HER2_G0_2411_106: ref_total=196, MIA_total=139, TP=96, TP_partial=37, FN=63, FP=6
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_62'
# Updated H2170_TOTAL_HER2_G2_2502_62: ref_total=143, MIA_total=109, TP=65, TP_partial=42, FN=36, FP=2
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_49'
# Updated H2170_LOW_HER2_G2_2502_49: ref_total=399, MIA_total=244, TP=67, TP_partial=176, FN=156, FP=1
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_23A'
# Updated H2170_LOW_HER2_G0_2411_23A: ref_total=25, MIA_total=19, TP=4, TP_partial=7, FN=14, FP=8
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_6'
# Updated H2170_HIGH_HER2_G0_2411_6: ref_total=288, MIA_total=302, TP=7, TP_partial=82, FN=199, FP=213
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_46'
# Updated H2170_LOW_HER2_G0_2411_46: ref_total=55, MIA_total=84, TP=15, TP_partial=14, FN=26, FP=55
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_1'
# Updated H2170_TOTAL_HER2_G1_2501_1: ref_total=84, MIA_total=87, TP=1, TP_partial=33, FN=50, FP=53
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_66'
# Updated H2170_HIGH_HER2_G0_2411_66: ref_total=355, MIA_total=302, TP=174, TP_partial=87, FN=94, FP=41
# Processing unique_id: 'H2170_LOW_HER2_G0_2411_2'
# Updated H2170_LOW_HER2_G0_2411_2: ref_total=45, MIA_total=54, TP=0, TP_partial=6, FN=39, FP=48
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_36'
# Updated H2170_TOTAL_HER2_G0_2411_36: ref_total=457, MIA_total=102, TP=48, TP_partial=48, FN=361, FP=6
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_86'
# Updated H2170_TOTAL_HER2_G0_2411_86: ref_total=252, MIA_total=116, TP=82, TP_partial=30, FN=140, FP=4
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_99'
# Updated H2170_LOW_HER2_G2_2502_99: ref_total=232, MIA_total=56, TP=21, TP_partial=22, FN=189, FP=13
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_39'
# Updated H2170_LOW_HER2_G2_2502_39: ref_total=119, MIA_total=86, TP=51, TP_partial=24, FN=44, FP=11
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_111'
# Updated H2170_HIGH_HER2_G1_2501_111: ref_total=173, MIA_total=74, TP=38, TP_partial=34, FN=101, FP=2
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_41'
# Updated H2170_HIGH_HER2_G0_2411_41: ref_total=180, MIA_total=169, TP=86, TP_partial=48, FN=46, FP=35
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_66'
# Updated H2170_HIGH_HER2_G1_2501_66: ref_total=916, MIA_total=64, TP=5, TP_partial=59, FN=852, FP=0
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_46'
# Updated H2170_TOTAL_HER2_G1_2501_46: ref_total=371, MIA_total=202, TP=59, TP_partial=137, FN=175, FP=6
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_73'
# Updated H2170_HIGH_HER2_G0_2411_73: ref_total=524, MIA_total=254, TP=66, TP_partial=145, FN=313, FP=43
# Processing unique_id: 'H2170_TOTAL_HER2_G1_2501_27'
# Updated H2170_TOTAL_HER2_G1_2501_27: ref_total=165, MIA_total=33, TP=21, TP_partial=12, FN=132, FP=0
# Processing unique_id: 'H2170_HIGH_HER2_G0_2411_100'
# Updated H2170_HIGH_HER2_G0_2411_100: ref_total=443, MIA_total=146, TP=81, TP_partial=57, FN=305, FP=8
# Processing unique_id: 'H2170_TOTAL_HER2_G0_2411_43'
# Updated H2170_TOTAL_HER2_G0_2411_43: ref_total=218, MIA_total=97, TP=60, TP_partial=30, FN=128, FP=7
# Processing unique_id: 'H2170_TOTAL_HER2_G2_2502_119'
# Updated H2170_TOTAL_HER2_G2_2502_119: ref_total=437, MIA_total=267, TP=151, TP_partial=90, FN=196, FP=26
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_40'
# Updated H2170_LOW_HER2_G2_2502_40: ref_total=339, MIA_total=222, TP=74, TP_partial=143, FN=122, FP=5
# Processing unique_id: 'H2170_HIGH_HER2_G2_2502_6'
# Updated H2170_HIGH_HER2_G2_2502_6: ref_total=381, MIA_total=144, TP=7, TP_partial=67, FN=307, FP=70
# Processing unique_id: 'H2170_LOW_HER2_G2_2502_65'
# Updated H2170_LOW_HER2_G2_2502_65: ref_total=132, MIA_total=51, TP=24, TP_partial=26, FN=82, FP=1
# Processing unique_id: 'H2170_HIGH_HER2_G1_2501_25'
# Updated H2170_HIGH_HER2_G1_2501_25: ref_total=115, MIA_total=22, TP=11, TP_partial=11, FN=93, FP=0
# MIA validation update complete. Updated CSV saved to /proj/brunk_ecdna_cv_project/Poorya/FACS-FISH_redistribution_NCIH2170/version_2_Acc_87/4_batch_process/Final_Output/FACS_241119_Output/updated_ecDNA_counts.csv
# Second part runtime: 2082.80 seconds

# %%
# Load the updated CSV
df = pd.read_csv(updated_csv_path)

# Compute summary statistics
summary = {
    "Total Images": len(df),
    "Average ref_total": df["ref_total"].mean(),
    "Average MIA_total": df["MIA_total"].mean(),
    "Average TP": df["TP"].mean(),
    "Average TP_partial": df["TP_partial"].mean(),
    "Average FN": df["FN"].mean(),
    "Average FP": df["FP"].mean(),
}

# Display summary
print("Summary Statistics:")
for key, value in summary.items():
    print(f"{key}: {value:.2f}")
# Out:
# Summary Statistics:
# Total Images: 1206.00
# Average ref_total: 254.56
# Average MIA_total: 123.65
# Average TP: 53.46
# Average TP_partial: 54.53
# Average FN: 146.56
# Average FP: 15.66

# %%
import os
import shutil

# Set the source directory
source_dir = output_folder

# Define the main groups and subcategories.
groups = {
    "_G0_": "G0",
    "_G1_": "G1",
    "_G2_": "G2"
}
subcategories = {
    "_HIGH_": "High_HER2",
    "_LOW_": "Low_HER2",
    "_TOTAL_": "Total_HER2"
}

# Create the folder structure if it doesn't already exist
for group_folder in groups.values():
    for sub_folder in subcategories.values():
        os.makedirs(os.path.join(source_dir, group_folder, sub_folder), exist_ok=True)

# Iterate over each file in the source directory
for filename in os.listdir(source_dir):
    file_path = os.path.join(source_dir, filename)
    
    # Skip directories to only process files
    if not os.path.isfile(file_path):
        continue

    # Determine the group folder based on filename content
    group_folder = None
    for key, folder in groups.items():
        if key in filename:
            group_folder = folder
            break
    
    # If no group was found, skip this file
    if group_folder is None:
        continue

    # Determine the subcategory folder based on filename content
    sub_folder = None
    for key, folder in subcategories.items():
        if key in filename:
            sub_folder = folder
            break
    
    # If no subcategory was found, skip this file
    if sub_folder is None:
        continue

    # Build the destination path
    dest_path = os.path.join(source_dir, group_folder, sub_folder, filename)
    
    # Move the file to the new folder
    shutil.move(file_path, dest_path)
    #print(f"Moved {filename} to {dest_path}")


# Create a Summary folder for CSV and JSON files
summary_folder = os.path.join(source_dir, "Summary")
os.makedirs(summary_folder, exist_ok=True)

# Move CSV and JSON files
for file in ["metrics_summary.csv", "updated_ecDNA_counts.csv", "ref_objects.json"]:
    src = os.path.join(source_dir, file)
    dst = os.path.join(summary_folder, file)
    if os.path.exists(src):
        shutil.move(src, dst)
        print(f"Moved {file} to {dst}")
# Out:
# Moved metrics_summary.csv to /proj/brunk_ecdna_cv_project/Poorya/FACS-FISH_redistribution_NCIH2170/version_2_Acc_87/4_batch_process/Final_Output/FACS_241119_Output/Summary/metrics_summary.csv
# Moved updated_ecDNA_counts.csv to /proj/brunk_ecdna_cv_project/Poorya/FACS-FISH_redistribution_NCIH2170/version_2_Acc_87/4_batch_process/Final_Output/FACS_241119_Output/Summary/updated_ecDNA_counts.csv
# Moved ref_objects.json to /proj/brunk_ecdna_cv_project/Poorya/FACS-FISH_redistribution_NCIH2170/version_2_Acc_87/4_batch_process/Final_Output/FACS_241119_Output/Summary/ref_objects.json

# %% [markdown]
# ## Acknowledgment
#
# **Use of AI-Based Code Generation and Editing Tools**
# This project was enhanced by the use of AI tools—ChatGPT, Grok, and Copilot—which played significant roles in improving the code, explanations, and overall presentation of the work.
#
# ### Specific Contributions
#
# - **ChatGPT**:
#   - Added comments to various functions to improve code readability and understanding.
#   - Assisted in optimizing functions and replacing less effective ones, leading to better performance and results.
#   - Provided clear, simplified explanations of complex concepts to make the content more accessible.
#   - Edited text for grammatical accuracy, clarity, and an appropriate tone.
#
# - **Grok**:
#   - Contributed to adding comments to functions for better documentation.
#   - Helped optimize functions and suggested replacements that improved the project’s outcomes.
#   - Assisted in refining explanations to ensure they were concise and easy to understand.
#
#
# All three tools—ChatGPT, Grok, and Copilot—were used to simplify explanations, making them clearer and more accessible. They also assisted in editing the grammar and tone of the text to improve readability and professionalism.
#
# - **Iterative Refinement Process:**
# For most parts of this project, I provided the same prompts to ChatGPT, Grok, and Copilot to compare their responses. I then asked each tool to evaluate the outputs of the others and provide feedback. This feedback was shared back with the tools, allowing them to refine their suggestions iteratively. This process ensured that the final code, explanations, and results were optimized for accuracy, clarity, and effectiveness.
#
# ### Citations
#
# - OpenAI. (2023). ChatGPT (Version o3-mini-high for code and logics & Version 4.5 for text editing) Large language model. https://openai.com/chatgpt
# - Grok (2023). xAI.(Version 3.0). Used for text generation and code refinement in this project. https://xai.com/grok
# - Microsoft Copilot (an AI assistant developed by Microsoft),
